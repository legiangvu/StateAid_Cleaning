# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import re
from difflib import SequenceMatcher
from rapidfuzz import fuzz, process
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import as_completed
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map
from contextlib import contextmanager
import time
from joblib import Parallel, delayed
from multiprocessing import Pool, cpu_count
import math
from collections import defaultdict
import pyarrow as pa
import pyarrow.parquet as pq
import unicodedata

# %% [markdown]
# # Set File Path and Prefix

# %%
# Define the file path and the prefix 'GER' for the CSV files
file_path = os.path.expanduser("~/Documents/IMT-Lucca/Policy-Learning/StateAid") # Replace with the actual path to your folder
cleaning_path = os.path.join(file_path, 'StateAid_Cleaning')
data_path = os.path.join(file_path, 'Data/GER')
prefix = 'Raw_GER'

# %%
raw_path = os.path.join(data_path, 'Raw')
print(f"Raw path: {raw_path}")
# Out:
# Raw path: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/Raw

# %%
# The raw data files from the state aid register have the prefix 'GER' followed by the year
# List all files in the directory with the specified prefix
csv_files = [f for f in os.listdir(raw_path) if f.startswith(prefix) and f.endswith('.csv')]

# Display the list of CSV files to be merged
csv_files
# Out:
# ['Raw_GER_2016.csv',
#  'Raw_GER_2017.csv',
#  'Raw_GER_2018.csv',
#  'Raw_GER_2019.csv',
#  'Raw_GER_2020.csv',
#  'Raw_GER_2021.csv',
#  'Raw_GER_2022.csv',
#  'Raw_GER_2023-25.csv']

# %% [markdown]
# # List and Read CSV Files
# List all CSV files in the directory with the specified prefix and read them into pandas DataFrames.

# %%
# Read each CSV file into a pandas DataFrame and store them in a list
dataframes = [pd.read_csv(os.path.join(raw_path, file)) for file in csv_files]

# Display the first few rows of each DataFrame to verify the contents
#for df in dataframes:
    #display(df.head())
# Out:
# /tmp/ipykernel_43744/2748973902.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes = [pd.read_csv(os.path.join(raw_path, file)) for file in csv_files]
# /tmp/ipykernel_43744/2748973902.py:2: DtypeWarning: Columns (13,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes = [pd.read_csv(os.path.join(raw_path, file)) for file in csv_files]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                Aid Measure Title  \
# 0  Reform of support for cogeneration in Germany
# 1  Reform of support for cogeneration in Germany
# 2  Reform of support for cogeneration in Germany
# 3  Reform of support for cogeneration in Germany
# 4  Reform of support for cogeneration in Germany
#
#                           Aid Measure Title [EN] SA.Number      Ref-no.  \
# 0  Reform of support for cogeneration in Germany  SA.42393  TM-10115165
# 1  Reform of support for cogeneration in Germany  SA.42393  TM-10115132
# 2  Reform of support for cogeneration in Germany  SA.42393  TM-10115133
# 3  Reform of support for cogeneration in Germany  SA.42393  TM-10115135
# 4  Reform of support for cogeneration in Germany  SA.42393  TM-10115137
#
#   National ID                   Name of the beneficiary  \
# 0  HRB 502044                      Th�ringer Energie AG
# 1    HRB 7173                                Mainova AG
# 2    HRB 7173                                Mainova AG
# 3  HRB 101879        Michelin Reifenwerke AG & Co. KGaA
# 4    HRA 7828  Molkerei Meggle Wasserburg GmbH & Co. KG
#
#                  Name of the beneficiary [EN]        Beneficiary Type  ...  \
# 0      Technically speaking Ringer Energie AG  Only large enterprises  ...
# 1                                  Mainova AG  Only large enterprises  ...
# 2                                  Mainova AG  Only large enterprises  ...
# 3           Michelin Tyreswerke AG & Co. KGaA  Only large enterprises  ...
# 4  ﻿Molkerei Megatle Wasserburg GmbH & Co. kg  Only large enterprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                               4162129      EUR       06/12/2016
# 1                                594642      EUR       05/12/2016
# 2                               2754961      EUR       28/11/2016
# 3                                656028      EUR       01/09/2016
# 4                               2017152      EUR       30/11/2016
#
#                          Granting Authority Name  \
# 0  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 1  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 2  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 3  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 4  Bundesamt für Wirtschaft und Ausfuhrkontrolle
#
#                      Granting Authority Name [EN]  Published Date  \
# 0  Federal Office of Economics and Export Control      05/10/2018
# 1  Federal Office of Economics and Export Control      05/10/2018
# 2  Federal Office of Economics and Export Control      05/10/2018
# 3  Federal Office of Economics and Export Control      05/10/2018
# 4  Federal Office of Economics and Export Control      05/10/2018
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0              NaN                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0  DE - Support of renewable electricity and redu...
# 1  DE - Support of renewable electricity and redu...
# 2  DE - Support of renewable electricity and redu...
# 3  DE - Support of renewable electricity and redu...
# 4  DE - Support of renewable electricity and redu...
#
#                               Aid Measure Title [EN] SA.Number      Ref-no.  \
# 0  ﻿De — Support of renewable electricity as a re...  SA.33995  TM-10116030
# 1  ﻿De — Support of renewable electricity as a re...  SA.33995  TM-10116140
# 2  ﻿De — Support of renewable electricity as a re...  SA.33995  TM-10116141
# 3  ﻿De — Support of renewable electricity as a re...  SA.33995  TM-10116142
# 4  ﻿De — Support of renewable electricity as a re...  SA.33995  TM-10116143
#
#     National ID                      Name of the beneficiary  \
# 0  HRA  6236 FL                     Wöhrden DK GmbH & Co. KG
# 1   DE284660287     WP Sachsen-Anhalt Süd Zwölf GmbH & Co.KG
# 2   DE284660295  WP Sachsen-Anhalt Süd Dreizehn GmbH & Co.KG
# 3  15/292/29373           Solarpark Ziegeleiweg Kremmen GmbH
# 4  15/292/08006                     Solarpark Rapshagen GmbH
#
#                   Name of the beneficiary [EN]  \
# 0                  ﻿Wöhrenden DK GmbH & Co. kg
# 1        ﻿Saxony-Anhalt South 12 GmbH & Co. kg
# 2  ﻿Saxony-Anhalt South Thirteen GmbH & Co. kg
# 3      ﻿Solarpark brick and bewegen route GmbH
# 4                 ﻿Oilseed rape Hraphagen GmbH
#
#                      Beneficiary Type  ...  \
# 0  Small and medium-sized entreprises  ...
# 1  Small and medium-sized entreprises  ...
# 2  Small and medium-sized entreprises  ...
# 3  Small and medium-sized entreprises  ...
# 4  Small and medium-sized entreprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                574191      EUR       31/07/2017
# 1                             509034.65      EUR       31/07/2017
# 2                             549141.12      EUR       31/07/2017
# 3                            1079295.04      EUR       31/07/2017
# 4                            1676784.33      EUR       31/07/2017
#
#                              Granting Authority Name  \
# 0  Übertragungsnetzbetreiber (50Hertz Transmissio...
# 1  Übertragungsnetzbetreiber (50Hertz Transmissio...
# 2  Übertragungsnetzbetreiber (50Hertz Transmissio...
# 3  Übertragungsnetzbetreiber (50Hertz Transmissio...
# 4  Übertragungsnetzbetreiber (50Hertz Transmissio...
#
#                         Granting Authority Name [EN]  Published Date  \
# 0  Transmission System Operator (50Hertz Transmis...      15/10/2018
# 1  Transmission System Operator (50Hertz Transmis...      15/10/2018
# 2  Transmission System Operator (50Hertz Transmis...      15/10/2018
# 3  Transmission System Operator (50Hertz Transmis...      15/10/2018
# 4  Transmission System Operator (50Hertz Transmis...      15/10/2018
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0              NaN                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0  Richtlinie zur Förderung von Forschungsvorhabe...
# 1            Photonics Research. R&D-scheme. Germany
# 2  Bund: National Framework on granting State aid...
# 3      Reform of support for cogeneration in Germany
# 4      Reform of support for cogeneration in Germany
#
#                               Aid Measure Title [EN] SA.Number      Ref-no.  \
# 0  ﻿Directive promoting research on improving exp...  SA.50601  TM-10109895
# 1          Photonics Research. R & D scheme. Germany  SA.32795  TM-10114424
# 2  Federal authorities: National Framework on gra...  SA.40354  TM-10109807
# 3      Reform of support for cogeneration in Germany  SA.42393  TM-10115166
# 4      Reform of support for cogeneration in Germany  SA.42393  TM-10115169
#
#                           National ID             Name of the beneficiary  \
# 0                      HRB 680693 Ulm        WITTENSTEIN cyber motor GmbH
# 1  HRB 280355 AG Freiburg im Breisgau                             SICK AG
# 2                                 xxx                        Mader Tobias
# 3                            HRA 5243  T�nnies Lebensmittel GmbH & Co. KG
# 4                           HRB 10216          Urbana Energiedienste GmbH
#
#       Name of the beneficiary [EN]                    Beneficiary Type  ...  \
# 0    ﻿WITTENSTEIN Cyber Motor GmbH              Only large enterprises  ...
# 1                          SICK AG              Only large enterprises  ...
# 2                    ﻿Mader Tobias  Small and medium-sized entreprises  ...
# 3  ﻿T kt nnices Food GmbH & Co. kg              Only large enterprises  ...
# 4      ﻿Urbana Energiedienste GmbH              Only large enterprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                672924      EUR       24/07/2018
# 1                                725930      EUR       24/09/2018
# 2                               86342.6      EUR       04/05/2018
# 3                               1209918      EUR       12/04/2018
# 4                               1036127      EUR       16/01/2018
#
#                          Granting Authority Name  \
# 0    Bundesministerium für Bildung und Forschung
# 1    Bundesministerium für Bildung und Forschung
# 2                      Landratsamt Bodenseekreis
# 3  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 4  Bundesamt für Wirtschaft und Ausfuhrkontrolle
#
#                      Granting Authority Name [EN]  Published Date  \
# 0      Federal Ministry of Education and Research      25/09/2018
# 1      Federal Ministry of Education and Research      01/10/2018
# 2               ﻿Bodenseekreis district authority      04/10/2018
# 3  Federal Office of Economics and Export Control      05/10/2018
# 4  Federal Office of Economics and Export Control      05/10/2018
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0              NaN                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0               Seedfonds Niedersachsen - NSeed [NI]
# 1  Vorschrift der Stadt Freiburg über die Förderu...
# 2      Reform of support for cogeneration in Germany
# 3      Reform of support for cogeneration in Germany
# 4      Reform of support for cogeneration in Germany
#
#                               Aid Measure Title [EN]  SA.Number      Ref-no.  \
# 0                Seed Fund Lower Saxony — NSeed [NI]  SA.102217  TM-11882783
# 1  Rule of the City of Freiburg on the promotion ...   SA.47123  TM-10096769
# 2      Reform of support for cogeneration in Germany   SA.42393  TM-10221354
# 3      Reform of support for cogeneration in Germany   SA.42393  TM-10221358
# 4      Reform of support for cogeneration in Germany   SA.42393  TM-10221454
#
#                      National ID        Name of the beneficiary  \
# 0                    DE305701255                 B&S Media GmbH
# 1  HRB 952 Registerger. Freiburg         Freiburger Verkehrs AG
# 2                        HRB 560           Stadtwerke Aachen AG
# 3                        HRB 501           Stadtwerke Burg GmbH
# 4                     GnR 375 FL  Energiegenossenschaft F�hr eG
#
#   Name of the beneficiary [EN]                    Beneficiary Type  ...  \
# 0         B &amp; S Media GmbH  Small and medium-sized entreprises  ...
# 1     Freundurger Transport AG              Only large enterprises  ...
# 2                          NaN              Only large enterprises  ...
# 3                          NaN  Small and medium-sized entreprises  ...
# 4                          NaN  Small and medium-sized entreprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                500000      EUR       15/08/2019
# 1                             938820.29      EUR       07/10/2019
# 2                                547027      EUR       16/09/2019
# 3                                678298      EUR       29/08/2019
# 4                                663923      EUR       05/08/2019
#
#                          Granting Authority Name  \
# 0                                          NBank
# 1                                 Stadt Freiburg
# 2  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 3  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 4  Bundesamt für Wirtschaft und Ausfuhrkontrolle
#
#                      Granting Authority Name [EN]  Published Date  \
# 0                                           NBank      13/09/2023
# 1                                City of Freiburg      10/04/2018
# 2  Federal Office of Economics and Export Control      16/11/2020
# 3  Federal Office of Economics and Export Control      16/11/2020
# 4  Federal Office of Economics and Export Control      16/11/2020
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0            NBank                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                Aid Measure Title  \
# 0  Reform of support for cogeneration in Germany
# 1  Reform of support for cogeneration in Germany
# 2  Reform of support for cogeneration in Germany
# 3  Reform of support for cogeneration in Germany
# 4  Reform of support for cogeneration in Germany
#
#                           Aid Measure Title [EN] SA.Number      Ref-no.  \
# 0  Reform of support for cogeneration in Germany  SA.42393  TM-10221353
# 1  Reform of support for cogeneration in Germany  SA.42393  TM-10221355
# 2  Reform of support for cogeneration in Germany  SA.42393  TM-10221356
# 3  Reform of support for cogeneration in Germany  SA.42393  TM-10221456
# 4  Reform of support for cogeneration in Germany  SA.42393  TM-10221458
#
#   National ID              Name of the beneficiary  \
# 0  GnR 720099                       BWO Energie eG
# 1  HRA 105947      SWM Infrastruktur GmbH & Co. KG
# 2    HRB 2847   Stadtwerke Ingolstadt Energie GmbH
# 3    HRB 3896  Energieservice Westfalen Weser GmbH
# 4    HRB 3420              Stadtwerke Detmold GmbH
#
#   Name of the beneficiary [EN]                    Beneficiary Type  ...  \
# 0                          NaN  Small and medium-sized entreprises  ...
# 1                          NaN              Only large enterprises  ...
# 2                          NaN              Only large enterprises  ...
# 3                          NaN              Only large enterprises  ...
# 4                          NaN  Small and medium-sized entreprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                688921      EUR       30/07/2020
# 1                                654115      EUR       23/07/2020
# 2                               1097253      EUR       10/09/2020
# 3                                537066      EUR       14/07/2020
# 4                                552565      EUR       25/08/2020
#
#                          Granting Authority Name  \
# 0  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 1  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 2  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 3  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 4  Bundesamt für Wirtschaft und Ausfuhrkontrolle
#
#                      Granting Authority Name [EN]  Published Date  \
# 0  Federal Office of Economics and Export Control      16/11/2020
# 1  Federal Office of Economics and Export Control      16/11/2020
# 2  Federal Office of Economics and Export Control      16/11/2020
# 3  Federal Office of Economics and Export Control      16/11/2020
# 4  Federal Office of Economics and Export Control      16/11/2020
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0              NaN                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0               Seedfonds Niedersachsen - NSeed [NI]
# 1  Richtlinie über die Gewährung von Zuwendungen ...
# 2         Richtlinie Digitalisierung im Verkehr [NI]
# 3  Implementierung eines wetterunabhängigen und h...
# 4  Implementierung eines wetterunabhängigen und h...
#
#                               Aid Measure Title [EN]  SA.Number      Ref-no.  \
# 0                Seed Fund Lower Saxony — NSeed [NI]  SA.102217  TM-11882792
# 1  Guidelines on the granting of grants for the s...   SA.58627  TM-11882822
# 2                   Digital Transport Directive [NI]   SA.60329  TM-11884300
# 3  Implementation of a weather-independent and hi...   SA.64477  TM-11884027
# 4  Implementation of a weather-independent and hi...   SA.64478  TM-11884028
#
#      National ID                            Name of the beneficiary  \
# 0     HRB 209437                           DREEMS e-mobilities GmbH
# 1  DE 811 231 08  Technische Universität Berlin Fachgebiet Flugm...
# 2       HRB 9748                     Oecon Products & Services GmbH
# 3      HRB 53050                    TÜV Rheinland InterTraffic GmbH
# 4   HRB 192096 B                                        ViaVan GmbH
#
#                         Name of the beneficiary [EN]  \
# 0                           DREEMS e-Mobilities GmbH
# 1  Technical University of Berlin, Department of ...
# 2                                                NaN
# 3                                                NaN
# 4                                        ViaVan GmbH
#
#                      Beneficiary Type  ...  \
# 0  Small and medium-sized entreprises  ...
# 1              Only large enterprises  ...
# 2  Small and medium-sized entreprises  ...
# 3              Only large enterprises  ...
# 4              Only large enterprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                500000      EUR       29/06/2021
# 1                                509300      EUR       09/03/2021
# 2                               1206000      EUR       18/03/2021
# 3                             893123.89      EUR       23/02/2021
# 4                            1013563.26      EUR       23/02/2021
#
#                          Granting Authority Name  \
# 0                                          NBank
# 1                                          NBank
# 2                                          NBank
# 3  Bundesanstalt für Verwaltungsdienstleistungen
# 4  Bundesanstalt für Verwaltungsdienstleistungen
#
#    Granting Authority Name [EN]  Published Date Entrusted Entity  \
# 0                         NBank      13/09/2023            NBank
# 1                         NBank      13/09/2023              NaN
# 2                         NBank      13/09/2023              NaN
# 3   Federal government services      13/09/2023              NaN
# 4   Federal government services      13/09/2023              NaN
#
#   Financial Intermediaries Third country outside of the EU
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0  Aufbau eines Innovationsclusters für Künstlich...
# 1  Germany - Amendment of the Federal aid scheme ...
# 2  Germany - Amendment of the Federal aid scheme ...
# 3  Germany - Amendment of the Federal aid scheme ...
# 4  Bund-Länder-Gemeinschaftsaufgabe "Verbesserung...
#
#                               Aid Measure Title [EN]  SA.Number      Ref-no.  \
# 0  Building an innovation cluster on Artificial I...  SA.103715  TM-11882798
# 1  Germany – Amendment of the Federal aid scheme ...  SA.103346  TM-11774519
# 2  Germany – Amendment of the Federal aid scheme ...  SA.103346  TM-11774560
# 3  Germany – Amendment of the Federal aid scheme ...  SA.103346  TM-11774509
# 4  Federal Government/Länder joint task “Improvem...  SA.101541  TM-11772408
#
#     National ID                           Name of the beneficiary  \
# 0    HRB 216532  CDC - Coppenrath Digital Innovation Cluster GmbH
# 1  DE 310625283        Spedition Artur Kossack Inhaberin Erna Dix
# 2      HRB 2854                            Strobel Quarzsand GmbH
# 3   DE251273055                             Gruber Logistics GmbH
# 4   DE317051578                                        Heise GmbH
#
#                        Name of the beneficiary [EN]  \
# 0  CDC – Coppenrath Digital Innovation Cluster GmbH
# 1   Freight forwarding Artur Kossack Owner Erna Dix
# 2                            Strobel Quarzsand GmbH
# 3                             Gruber Logistics GmbH
# 4                                        Heise GmbH
#
#                      Beneficiary Type  ...  \
# 0  Small and medium-sized entreprises  ...
# 1  Small and medium-sized entreprises  ...
# 2  Small and medium-sized entreprises  ...
# 3              Only large enterprises  ...
# 4  Small and medium-sized entreprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                               4909248      EUR       30/06/2022
# 1                               1206800      EUR       19/12/2022
# 2                              384969.6      EUR       15/12/2022
# 3                               5277080      EUR       15/12/2022
# 4                                601060      EUR       09/12/2022
#
#       Granting Authority Name               Granting Authority Name [EN]  \
# 0                       NBank                                      NBank
# 1  Bundesamt für Güterverkehr  Federal Office for the Transport of Goods
# 2  Bundesamt für Güterverkehr  Federal Office for the Transport of Goods
# 3  Bundesamt für Güterverkehr  Federal Office for the Transport of Goods
# 4                       NBank                                      NBank
#
#    Published Date Entrusted Entity Financial Intermediaries  \
# 0      13/09/2023              NaN                      NaN
# 1      29/08/2023              NaN                      NaN
# 2      29/08/2023              NaN                      NaN
# 3      29/08/2023              NaN                      NaN
# 4      01/09/2023              NaN                      NaN
#
#   Third country outside of the EU
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 26 columns]
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                    Aid Measure Title  \
# 0             Hessen - Digitalisation of agriculture
# 1             Hessen - Digitalisation of agriculture
# 2  AIAMO - Artificial Intelligence and Mobility/K...
# 3  Germany - Evaluation plan for the block exempt...
# 4  AIAMO - Artificial Intelligence and Mobility/K...
#
#                               Aid Measure Title [EN]  SA.Number      Ref-no.  \
# 0             Hessen — Digitalisation of agriculture   SA.60603  TM-11881445
# 1             Hessen — Digitalisation of agriculture   SA.60603  TM-11881452
# 2  AIAMO – Artificial Intelligence and Mobility [...  SA.108709  TM-11882873
# 3  Germany — Evaluation plan for the block exempt...   SA.56245  TM-11881220
# 4  AIAMO – Artificial Intelligence and Mobility [...  SA.108704  TM-11882872
#
#       National ID                            Name of the beneficiary  \
# 0       PI 856435                                       Michael Dörr
# 1      PI 9019611                                        Martin Kuhn
# 2       HRB 14000  Robert Bosch Gesellschaft mit beschränkter Haf...
# 3      HRB 196674                                         Shore GmbH
# 4  DE 147 839 419  Forschungsinstitut für Kraftfahrwesen und Fahr...
#
#                         Name of the beneficiary [EN]  \
# 0                                       Michael Dörr
# 1                                        Martin Kuhn
# 2                                                NaN
# 3                                         Shore GmbH
# 4  Research Institute for Motor Vehicles and Moto...
#
#                      Beneficiary Type  ...  \
# 0  Small and medium-sized entreprises  ...
# 1  Small and medium-sized entreprises  ...
# 2              Only large enterprises  ...
# 3  Small and medium-sized entreprises  ...
# 4  Small and medium-sized entreprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                                 34924      EUR       08/05/2023
# 1                                 25252      EUR       16/05/2023
# 2                            1076027.71      EUR       29/06/2023
# 3                 > 500,000 - 1,000,000      EUR       13/09/2023
# 4                             819243.87      EUR       29/06/2023
#
#                          Granting Authority Name  \
# 0                     Regierungspräsidium Gießen
# 1                     Regierungspräsidium Gießen
# 2  Bundesanstalt für Verwaltungsdienstleistungen
# 3                       Finanzamt München Abt. 3
# 4  Bundesanstalt für Verwaltungsdienstleistungen
#
#       Granting Authority Name [EN] Published Date Entrusted Entity  \
# 0       Regierungspräsidium Gießen     05/09/2023              NaN
# 1       Regierungspräsidium Gießen     05/09/2023              NaN
# 2      Federal government services     13/09/2023              NaN
# 3  Munich Tax Office, Department 3     13/09/2023              NaN
# 4      Federal government services     13/09/2023              NaN
#
#   Financial Intermediaries Third country outside of the EU
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Merge DataFrames
# Merge all the DataFrames into a single DataFrame.

# %%
# Merge all the DataFrames into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the merged DataFrame to verify the contents
#display(merged_df.head())
# Out:
#    Country Another Beneficiary Member State  \
# 0  Germany                          Germany
# 1  Germany                          Germany
# 2  Germany                          Germany
# 3  Germany                          Germany
# 4  Germany                          Germany
#
#                                Aid Measure Title  \
# 0  Reform of support for cogeneration in Germany
# 1  Reform of support for cogeneration in Germany
# 2  Reform of support for cogeneration in Germany
# 3  Reform of support for cogeneration in Germany
# 4  Reform of support for cogeneration in Germany
#
#                           Aid Measure Title [EN] SA.Number      Ref-no.  \
# 0  Reform of support for cogeneration in Germany  SA.42393  TM-10115165
# 1  Reform of support for cogeneration in Germany  SA.42393  TM-10115132
# 2  Reform of support for cogeneration in Germany  SA.42393  TM-10115133
# 3  Reform of support for cogeneration in Germany  SA.42393  TM-10115135
# 4  Reform of support for cogeneration in Germany  SA.42393  TM-10115137
#
#   National ID                   Name of the beneficiary  \
# 0  HRB 502044                      Th�ringer Energie AG
# 1    HRB 7173                                Mainova AG
# 2    HRB 7173                                Mainova AG
# 3  HRB 101879        Michelin Reifenwerke AG & Co. KGaA
# 4    HRA 7828  Molkerei Meggle Wasserburg GmbH & Co. KG
#
#                  Name of the beneficiary [EN]        Beneficiary Type  ...  \
# 0      Technically speaking Ringer Energie AG  Only large enterprises  ...
# 1                                  Mainova AG  Only large enterprises  ...
# 2                                  Mainova AG  Only large enterprises  ...
# 3           Michelin Tyreswerke AG & Co. KGaA  Only large enterprises  ...
# 4  ﻿Molkerei Megatle Wasserburg GmbH & Co. kg  Only large enterprises  ...
#
#   Nominal Amount, expressed as full amount  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Aid element, expressed as full amount Currency Date of granting  \
# 0                               4162129      EUR       06/12/2016
# 1                                594642      EUR       05/12/2016
# 2                               2754961      EUR       28/11/2016
# 3                                656028      EUR       01/09/2016
# 4                               2017152      EUR       30/11/2016
#
#                          Granting Authority Name  \
# 0  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 1  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 2  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 3  Bundesamt für Wirtschaft und Ausfuhrkontrolle
# 4  Bundesamt für Wirtschaft und Ausfuhrkontrolle
#
#                      Granting Authority Name [EN] Published Date  \
# 0  Federal Office of Economics and Export Control     05/10/2018
# 1  Federal Office of Economics and Export Control     05/10/2018
# 2  Federal Office of Economics and Export Control     05/10/2018
# 3  Federal Office of Economics and Export Control     05/10/2018
# 4  Federal Office of Economics and Export Control     05/10/2018
#
#   Entrusted Entity Financial Intermediaries Third country outside of the EU
# 0              NaN                      NaN                             NaN
# 1              NaN                      NaN                             NaN
# 2              NaN                      NaN                             NaN
# 3              NaN                      NaN                             NaN
# 4              NaN                      NaN                             NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Save Merged DataFrame
# Save the merged DataFrame to a new CSV file.

# %%
# Save the merged DataFrame to a new CSV file
output_file_path = os.path.join(data_path, 'Raw/merged_GER.csv')  # Replace with the desired output file path
merged_df.to_csv(output_file_path, index=False)

# %% [markdown]
# # Get NID from StateAid Register

# %% [markdown]
# Get National ID from State Aid data to get search on orbis

# %%
df_filtered = pd.read_csv(os.path.join(data_path, 'Raw/merged_GER.csv'))
# Out:
# /tmp/ipykernel_51605/1693412780.py:1: DtypeWarning: Columns (13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_filtered = pd.read_csv(os.path.join(file_path, 'Raw/merged_GER.csv'))

# %%
# Keep only the 'National ID' columns
df_filtered = df_filtered[['National ID']]

# %%
# Filter rows that contain "Ust-IdNr" in the "National ID" column, case-insensitive
df_add_ustid_trade = df_filtered[df_filtered['National ID'].str.contains('ust', case=False, na=False) & df_filtered['National ID'].str.contains('id', case=False, na=False)]
# Filter rows that contain "Amtsgericht" in the "National ID" column, case-insensitive
df_amtsgericht = df_filtered[df_filtered['National ID'].str.contains('Amtsgericht', case=False, na=False)]

# Concatenate the filtered rows to df_add_ustid_trade
df_add_ustid_trade = pd.concat([df_add_ustid_trade, df_amtsgericht], ignore_index=True)

df_add_VR_trade = df_filtered.copy()

# %%
# Define the clean_ust_id function
def clean_ust_id(national_id):
    # Match the sequence 'DE' followed by digits, ignoring spaces and stopping at non-digit characters
    match = re.search(r'DE\s*\d{1,3}\s*\d{1,3}\s*\d{1,3}', national_id)
    if match:
        # Remove all spaces from the matched string
        return re.sub(r'\s+', '', match.group(0))
    return national_id  # Return the original national_id if no match is found

# Define a function to clean 'National ID' for Trade ID
def clean_amtsgericht(national_id):
    # Match the sequence 'HRA', 'HRB', 'HR A', 'HR B', or 'VR' followed by digits, ignoring spaces and special characters
    match = re.search(r'(HRA|HRB|HR\s*A|HR\s*B|VR)\s*\d+', national_id, re.IGNORECASE)
    if match:
        # Remove all spaces and special characters from the matched string
        return re.sub(r'[\s_()]+', '', match.group(0))
    return national_id  # Return the original national_id if no match is found

# Ensure 'National ID' column is of string type and handle NaN values
df_add_ustid_trade['National ID'] = df_add_ustid_trade['National ID'].fillna('').astype(str)
df_add_VR_trade['National ID'] = df_add_VR_trade['National ID'].fillna('').astype(str)

# Apply the cleaning functions to the appropriate rows
df_add_ustid_trade['National ID'] = df_add_ustid_trade.apply(
    lambda row: clean_ust_id(row['National ID']) if re.search(r'ust', row['National ID'], re.IGNORECASE) and re.search(r'id', row['National ID'], re.IGNORECASE) else row['National ID'],
    axis=1
)

df_add_ustid_trade['National ID'] = df_add_ustid_trade.apply(
    lambda row: clean_amtsgericht(row['National ID']) if re.search(r'Amtsgericht', row['National ID'], re.IGNORECASE) else row['National ID'],
    axis=1
)

df_add_VR_trade['National ID'] = df_add_VR_trade.apply(
    lambda row: clean_amtsgericht(row['National ID']),
    axis=1
)

df_nid = pd.concat([df_filtered, df_add_ustid_trade, df_add_VR_trade], ignore_index=True)

# %%
# Export
output_ustid_trade_path = os.path.join(data_path, 'NID_for_Orbis/NID_GER.csv')
df_nid.to_csv(output_ustid_trade_path, index=False)

# %% [markdown]
# # Clean Trade number files from Orbis

# %%
# Function to extract VAT and Tax numbers
def extract_numbers(vat_tax_number):
    if isinstance(vat_tax_number, str):
        parts = vat_tax_number.split('\n')
        if len(parts) == 2:
            return parts[0], parts[1]  # VAT, Tax
        elif len(parts) == 1:
            if 'DE' in parts[0]:  # Check if it contains 'DE'
                return parts[0], None  # VAT, No Tax
            else:
                return None, parts[0]  # No VAT, Tax
    return None, None  # Handle non-string or unexpected formats

# %%
# Datafiles from Orbis have prefix 'GER_TradeNo_'
#prefix_trade = 'GER_TradeNo_'
prefix_trade = 'GER_Trade'

trade_path = os.path.join(data_path, 'Raw_from_Orbis')

# List all Excel files in the directory with the specified prefix
xlsx_files = [f for f in os.listdir(trade_path) if f.startswith(prefix_trade) and f.endswith('.xlsx')]

# Process each Excel file
for xlsx_file in xlsx_files:
    # Load the Excel file into a DataFrame
    df_xlsx = pd.read_excel(os.path.join(trade_path, xlsx_file), sheet_name='Results')
    
    #Rename the first column to 'Index'
    df_xlsx.rename(columns={df_xlsx.columns[0]: 'Index'}, inplace=True)
    
    # Create a new column 'Tax number' and set it to NaN
    df_xlsx['Tax number'] = np.nan

    # Apply the extraction function
    df_xlsx[['VAT number', 'Tax number']] = df_xlsx['VAT/Tax number'].apply(extract_numbers).tolist()

    # Drop the original VAT/Tax number column
    df_xlsx = df_xlsx.drop('VAT/Tax number', axis=1)

    # Reorder the last three columns: VAT number, Trade register number, Tax number
    columns_order = df_xlsx.columns.tolist()  # Get the current column order as a list
    last_three_columns = ['VAT number', 'Trade register number', 'Tax number']  # Specify the desired order for the last three columns

    # Remove the last three columns from the current order and append them in the desired order
    columns_order = [col for col in columns_order if col not in last_three_columns] + last_three_columns

    # Reorder the DataFrame columns
    df_xlsx = df_xlsx[columns_order]
    
    # Define the output Excel file path
    output_file_path = os.path.join(data_path, 'Cleaned_from_Orbis',f"filtered_{xlsx_file}")
    
    # Save the filtered DataFrame to a new Excel file
    df_xlsx.to_excel(output_file_path, index=False)
    
    print(f"Filtered Excel file has been saved at: {output_file_path}")
# Out:
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_150001-300000.xlsx
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_300001-450000.xlsx
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_450001-600000.xlsx
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_600001-750000.xlsx
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_750001-856205.xlsx
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_TradeTaxVAT_1-150000.xlsx

# %% [markdown]
# # Clean Tax number file from Orbis

# %%
# Define the Excel file path
excel_file_path = os.path.join(data_path, 'Raw_from_Orbis/GER_TaxNo.xlsx')  # Replace with your Excel file path

# Load the Excel file into a DataFrame (assuming the sheet name is 'Results')
df = pd.read_excel(excel_file_path, sheet_name='Results')

# Create a new column 'Tax number' and initialize it with NaN
df['Tax number'] = np.nan

# Apply the extraction function
df[['VAT number', 'Tax number']] = df['VAT/Tax number'].apply(extract_numbers).tolist()

# Drop the original VAT/Tax number column
df = df.drop('VAT/Tax number', axis=1)

# Reorder the last three columns: VAT number, Trade register number, Tax number
columns_order = df.columns.tolist()  # Get the current column order as a list
last_three_columns = ['VAT number', 'Trade register number', 'Tax number']  # Specify the desired order for the last three columns

# Remove the last three columns from the current order and append them in the desired order
columns_order = [col for col in columns_order if col not in last_three_columns] + last_three_columns

# Reorder the DataFrame columns
df = df[columns_order]

# Define the output Excel file path
output_file_path = os.path.join(data_path, 'Cleaned_from_Orbis', 'filtered_GER_TaxNo.xlsx')  # Replace with your desired output Excel file path

# Save the filtered DataFrame to a new Excel file
df.to_excel(output_file_path, index=False)

print(f"Filtered Excel file has been saved at: {output_file_path}")

# %% [markdown]
# # Clean VAT number

# %%
# Define the Excel file path
excel_file_path = os.path.join(data_path, 'Raw_from_Orbis/GER_Ust-VAT.xlsx')  # Replace with your Excel file 

# Load the Excel file into a DataFrame (assuming the sheet name is 'Results')
df = pd.read_excel(excel_file_path, sheet_name='Results')

# Create a new column 'Tax number' and initialize it with NaN
df['Tax number'] = np.nan

# Apply the extraction function
df[['VAT number', 'Tax number']] = df['VAT/Tax number'].apply(extract_numbers).tolist()

# Drop the original VAT/Tax number column
df = df.drop('VAT/Tax number', axis=1)

# Reorder the last three columns: VAT number, Trade register number, Tax number
columns_order = df.columns.tolist()  # Get the current column order as a list
last_three_columns = ['VAT number', 'Trade register number', 'Tax number']  # Specify the desired order for the last three columns

# Remove the last three columns from the current order and append them in the desired order
columns_order = [col for col in columns_order if col not in last_three_columns] + last_three_columns

# Reorder the DataFrame columns
df = df[columns_order]

# Define the output Excel file path
output_file_path = os.path.join(data_path, 'Cleaned_from_Orbis', 'filtered_GER_Ust-VAT.xlsx')  # Replace with your desired output Excel file path

# Save the filtered DataFrame to a new Excel file
df.to_excel(output_file_path, index=False)

print(f"Filtered Excel file has been saved at: {output_file_path}")
# Out:
# Filtered Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/filtered_GER_Ust-VAT.xlsx

# %% [markdown]
# # Merge all national id types

# %%
prefix_filtered = 'filtered_GER_'

cleaned_path = os.path.join(data_path, 'Cleaned_from_Orbis')

# List all Excel files in the directory with the specified prefix
xlsx_files = [f for f in os.listdir(cleaned_path) if f.startswith(prefix_filtered) and f.endswith('.xlsx')]

# Initialize an empty list to store DataFrames
dataframes = []

# Process each Excel file
for xlsx_file in xlsx_files:
    # Load the Excel file
    excel_path = os.path.join(cleaned_path, xlsx_file)
    xls = pd.ExcelFile(excel_path)
    
    # Check if the "Results" sheet exists, otherwise use the first sheet
    sheet_name = 'Results' if 'Results' in xls.sheet_names else xls.sheet_names[0]
    
    # Load the sheet into a DataFrame
    df = pd.read_excel(excel_path, sheet_name=sheet_name)
    
    #Remove the first column
    df = df.iloc[:, 1:]
    
    ## Remove the dash and the numbers following it in the 'BvD ID number'
    df['BvD ID number'] = df['BvD ID number'].str.replace(r'-\d+', '', regex=True)

    # Remove duplicates based on the cleaned 'BvD ID number'
    df = df.drop_duplicates(subset=['BvD ID number'], keep='first')
    

    # Ensure consistent data types
    df = df.astype(str)
    
    # Append the DataFrame to the list
    dataframes.append(df)

# Merge all the DataFrames into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Replace 'nan' string with actual NaN in the specified columns
merged_df[['Tax number', 'Trade register number', 'VAT number']] = merged_df[['Tax number', 'Trade register number', 'VAT number']].replace('nan', np.nan)

# Define the output Excel file path
output_file_path = os.path.join(data_path, 'Cleaned_from_Orbis' ,'found_NID_GER.xlsx')  # Replace with your desired output file path

# Save the merged DataFrame to a new Excel file
merged_df.to_excel(output_file_path, index=False)

print(f"Merged Excel file has been saved at: {output_file_path}")
# Out:
# Merged Excel file has been saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/StateAid_Cleaning/Cleaned_from_Orbis/found_NID_GER.xlsx

# %% [markdown]
# # Remove not-found firms from the register

# %%
# Define the path
csv_file_path = os.path.join(data_path, "Raw/merged_GER.csv")  # Replace with your CSV file path
xlsx_file_path = os.path.join(data_path, "Cleaned_from_Orbis/found_NID_GER.xlsx")  # Replace with your Excel file path

# Load the files
columns_to_load = ['Ref-no.','Name of the beneficiary','National ID']
df_csv = pd.read_csv(csv_file_path, usecols=columns_to_load, dtype={'National ID': str})
df_xlsx = pd.read_excel(xlsx_file_path, dtype={'VAT number': str, 'Trade register number': str, 'Tax number': str})

df_xlsx.rename(columns={'Tax number': 'taxno','Trade register number': 'tradeno', 'VAT number': 'vatno'}, inplace=True)
df_xlsx = df_xlsx.drop_duplicates(subset=['BvD ID number'], keep='first')

# %%
# Convert 'National ID' to string type
df_csv['National ID'] = df_csv['National ID'].astype(str)
df_xlsx['vatno'] = df_xlsx['vatno'].astype(str)
df_xlsx['tradeno'] = df_xlsx['tradeno'].astype(str)
df_xlsx['taxno'] = df_xlsx['taxno'].astype(str)

# Create the 'nid_indic' column 
#df_csv['nid_indic'] = df_csv['National ID'].apply(lambda x: 1 if re.search(r'\b(HRA|HRB|HR A|HR B|VR)\b', x, re.IGNORECASE) else 0)

df_csv['Name of the beneficiary'] = df_csv['Name of the beneficiary'].astype(str)
df_xlsx['Company name Latin alphabet'] = df_xlsx['Company name Latin alphabet'].astype(str)

# Rename the column without assigning the result back to df_xlsx
df_xlsx.rename(columns={'Company name\nLocal Alphabet': 'Company name Local Alphabet'}, inplace=True)
df_xlsx['Company name Local Alphabet'] = df_xlsx['Company name Local Alphabet'].astype(str)

# %%
# Create nid columns
df_csv['nidfororbis'] = df_csv['National ID']
df_csv = df_csv.drop_duplicates(subset=['National ID', 'Name of the beneficiary'], keep='first')
df_add_VR_trade = df_csv.copy()


# Filter rows that contain "Ust-IdNr" in the "National ID" column, case-insensitive
df_add_ustid_trade = df_csv[df_csv['nidfororbis'].str.contains('ust', case=False, na=False) & df_csv['nidfororbis'].str.contains('id', case=False, na=False)]
# Filter rows that contain "Amtsgericht" in the "National ID" column, case-insensitive
df_amtsgericht = df_csv[df_csv['nidfororbis'].str.contains('Amtsgericht', case=False, na=False)]

# Concatenate the filtered rows to df_add_ustid_trade
df_add_ustid_trade = pd.concat([df_add_ustid_trade, df_amtsgericht], ignore_index=True)

# Define the clean_ust_id function
def clean_ust_id(national_id):
    # Match the sequence 'DE' followed by digits, ignoring spaces and stopping at non-digit characters
    match = re.search(r'DE\s*\d{1,3}\s*\d{1,3}\s*\d{1,3}', national_id)
    if match:
        # Remove all spaces from the matched string
        return re.sub(r'\s+', '', match.group(0))
    return national_id  # Return the original national_id if no match is found

# Define a function to clean 'National ID' for Trade ID
def clean_amtsgericht(national_id):
    # Match the sequence 'HRA', 'HRB', 'HR A', 'HR B', or 'VR' followed by digits, ignoring spaces and special characters
    match = re.search(r'(HRA|HRB|HR\s*A|HR\s*B|VR)\s*\d+', national_id, re.IGNORECASE)
    if match:
        # Remove all spaces and special characters from the matched string
        return re.sub(r'[\s_()]+', '', match.group(0))
    return national_id  # Return the original national_id if no match is found

# Apply the cleaning functions to the appropriate rows
df_add_ustid_trade['nidfororbis'] = df_add_ustid_trade.apply(
    lambda row: clean_ust_id(row['nidfororbis']) if re.search(r'ust', row['nidfororbis'], re.IGNORECASE) and re.search(r'id', row['nidfororbis'], re.IGNORECASE) else row['nidfororbis'],
    axis=1
)

df_add_ustid_trade['nidfororbis'] = df_add_ustid_trade.apply(
    lambda row: clean_amtsgericht(row['nidfororbis']) if re.search(r'Amtsgericht', row['nidfororbis'], re.IGNORECASE) else row['nidfororbis'],
    axis=1
)

df_add_VR_trade['nidfororbis'] = df_add_VR_trade.apply(
    lambda row: clean_amtsgericht(row['nidfororbis']),
    axis=1
)

df_csv = pd.concat([df_csv, df_add_VR_trade, df_add_ustid_trade], ignore_index=True)

df_unique = df_csv.drop_duplicates(subset=['National ID', 'Name of the beneficiary'], keep='last')
#df_unique = df_unique.drop_duplicates(subset=['National ID'], keep='last')
#df_unique = df_csv
df_unique = df_unique.reset_index(drop=True)

# Step 1: Locate all .txt files with the prefix "not-found" in the folder
file_pattern = os.path.join(data_path, 'Raw_from_Orbis/not-found*.txt')  # Match all files starting with "not-found"
txt_files = glob.glob(file_pattern)

# Step 2: Read and merge all .txt files
merged_ids = pd.concat(
    [
        pd.DataFrame(
            {'National ID': [line.strip() for line in open(file, 'r', encoding='utf-8') if line.strip()]}
        )
        for file in txt_files
    ]
).drop_duplicates()

# Step 3: Drop rows in df_unique where 'National ID' matches any in the merged IDs
df_unique_filtered = df_unique[~df_unique['nidfororbis'].isin(merged_ids['National ID'])]
print(df_unique_filtered.columns)

df_unique_filtered['nid'] = df_unique_filtered.apply(lambda row: clean_ust_id(row['nidfororbis']), axis=1)
df_unique_filtered['nid'] = df_unique_filtered.apply(lambda row: clean_amtsgericht(row['nidfororbis']), axis=1)

df_unique_filtered.drop(columns=['nidfororbis'], inplace=True)
df_unique_filtered = df_unique_filtered.reset_index(drop=True)

# Display the resulting DataFrame
print(df_unique_filtered)
# Out:
# Index(['Ref-no.', 'National ID', 'Name of the beneficiary', 'nidfororbis'], dtype='object')
# /tmp/ipykernel_131502/1462588228.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique_filtered['nid'] = df_unique_filtered.apply(lambda row: clean_ust_id(row['nidfororbis']), axis=1)
#             Ref-no.                        National ID  \
# 0       TM-10115165                         HRB 502044
# 1       TM-10115132                           HRB 7173
# 2       TM-10115135                         HRB 101879
# 3       TM-10115137                           HRA 7828
# 4       TM-10115139                           HRB 1194
# ...             ...                                ...
# 144339  TM-12496237       HRB 14608 Amtsgericht Kassel
# 144340  TM-12496608    HRB 170858; Amtsgericht Hamburg
# 144341  TM-12546423         Amtsgericht Essen HRB 1433
# 144342  TM-12546450  Amtsgericht Ingolstadt HRA 102780
# 144343  TM-12546425        Amtsgericht Essen HRB 10740
#
#                          Name of the beneficiary        nid
# 0                           Th�ringer Energie AG  HRB502044
# 1                                     Mainova AG    HRB7173
# 2             Michelin Reifenwerke AG & Co. KGaA  HRB101879
# 3       Molkerei Meggle Wasserburg GmbH & Co. KG    HRA7828
# 4               Neubrandenburger Stadtwerke GmbH    HRB1194
# ...                                          ...        ...
# 144339                             EAM Netz GmbH   HRB14608
# 144340                     Artefact Germany GmbH  HRB170858
# 144341                      Iqony Fernwärme GmbH    HRB1433
# 144342           Stadtwerke Neuburg an der Donau  HRA102780
# 144343       Iqony Fernwärme Essen GmbH & Co. KG   HRB10740
#
# [144344 rows x 4 columns]
# /tmp/ipykernel_131502/1462588228.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique_filtered['nid'] = df_unique_filtered.apply(lambda row: clean_amtsgericht(row['nidfororbis']), axis=1)
# /tmp/ipykernel_131502/1462588228.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique_filtered.drop(columns=['nidfororbis'], inplace=True)

# %%
# Clean the "nid" column 
df_unique_filtered['nid'] = df_unique_filtered['nid'].str.replace(r'[\s()/]', '', regex=True)
df_xlsx['tradeno'] = df_xlsx['tradeno'].str.replace(r'[\s()/]', '', regex=True)
df_xlsx['vatno'] = df_xlsx['vatno'].str.replace(r'[\s()/]', '', regex=True)
df_xlsx['taxno'] = df_xlsx['taxno'].str.replace(r'[\s()/]', '', regex=True)

# %%
# Sample for testing
# Create a random sample from df_csv
sample_size = 1000  # Define the sample size
df_sample = df_unique_filtered.sample(n=sample_size, random_state=42)

# %%
df_sample_test = df_sample[df_sample['Name of the beneficiary'] == 'Tucan.ai GmbH']
df_xlsx_test = df_xlsx[df_xlsx['Company name Local Alphabet'] == 'TUCAN.AI GMBH']

# %%
# List of specific chunk indices to split further
specific_chunk_indices = [118, 215, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 
                          251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276,
                          277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289]

def preprocess_nid(nid):
    """Preprocess NID by removing special characters."""
    nid = str(nid)  # Ensure it's a string
    remove_chars = " .-()[]{}\\|,;:_"
    trans_table = str.maketrans("", "", remove_chars)
    return nid.translate(trans_table)

def preprocess_data(df_sample, df_xlsx):
    """Preprocess the data by cleaning NIDs."""
    df_sample = df_sample.copy()
    df_xlsx = df_xlsx.copy()
    df_sample['processed_nid'] = df_sample['nid'].apply(preprocess_nid)
    df_xlsx['processed_tradeno'] = df_xlsx['tradeno'].apply(preprocess_nid)
    df_xlsx['processed_vatno'] = df_xlsx['vatno'].apply(preprocess_nid)
    df_xlsx['processed_taxno'] = df_xlsx['taxno'].apply(preprocess_nid)
    return df_sample, df_xlsx

def match_chunk_unlimited(chunk_df, df_xlsx, threshold, output_dir, chunk_index):
    """Match a chunk of rows against all xlsx_nids and write results to disk in Parquet format."""
    results = []
    xlsx_tradeno = df_xlsx['processed_tradeno'].tolist()
    xlsx_vatno = df_xlsx['processed_vatno'].tolist()
    xlsx_taxno = df_xlsx['processed_taxno'].tolist()
    
    for _, sample_row in chunk_df.iterrows():
        sample_nid = sample_row['processed_nid']
        for idx in range(len(df_xlsx)):
            tradenoscore = fuzz.partial_ratio(sample_nid, xlsx_tradeno[idx])
            vatnoscore = fuzz.partial_ratio(sample_nid, xlsx_vatno[idx])
            taxnoscore = fuzz.partial_ratio(sample_nid, xlsx_taxno[idx])
            score = max(tradenoscore, vatnoscore, taxnoscore)
            if score >= threshold:
                matched_row = df_xlsx.iloc[idx]
                results.append({
                    'Ref-no.': sample_row['Ref-no.'],
                    'National ID': sample_row['National ID'],
                    'processed_nid': sample_nid,
                    'orbis_tradeno': matched_row['tradeno'],
                    'orbis_vatno': matched_row['vatno'],
                    'orbis_taxno': matched_row['taxno'],
                    'Name of the beneficiary': sample_row['Name of the beneficiary'],
                    'orbis_name': matched_row['Company name Local Alphabet'],
                    'bvd_id': matched_row['BvD ID number'],
                    'nidscore': score
                })
    
    # Write results to a temporary Parquet file
    temp_file_path = os.path.join(output_dir, f"chunk_{chunk_index}.parquet")
    pd.DataFrame(results).to_parquet(temp_file_path, index=False)
    return temp_file_path

def find_similar_nids_unlimited(df_sample, df_xlsx, threshold=70, chunk_size=50, output_dir="temp_results", n_jobs=-1):
    """Find similar NIDs and write intermediate results to disk in Parquet format."""
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Preprocess the data
    df_sample, df_xlsx = preprocess_data(df_sample, df_xlsx)

    # Split df_sample into chunks
    num_chunks = math.ceil(len(df_sample) / chunk_size)
    chunks = [df_sample.iloc[i * chunk_size:(i + 1) * chunk_size] for i in range(num_chunks)]

    # Check for already processed chunks
    processed_chunks = set(
        int(os.path.basename(file).split("_")[1].split(".")[0])  # Extract chunk index from file name
        for file in glob.glob(os.path.join(output_dir, "chunk_*.parquet"))
    )

    # Parallel processing
    temp_files = []
    with ProcessPoolExecutor() as executor:
        futures = []
        for chunk_index, chunk in enumerate(chunks):
            if chunk_index in processed_chunks:
                continue  # Skip already processed chunks
            
            # If the chunk index is in the specific list, split it further into 5 sub-chunks
            if chunk_index in specific_chunk_indices:
                sub_chunk_size = math.ceil(len(chunk) / 100)
                sub_chunks = [chunk.iloc[i * sub_chunk_size:(i + 1) * sub_chunk_size] for i in range(100)]
                for sub_chunk_index, sub_chunk in enumerate(sub_chunks):
                    futures.append(executor.submit(
                        match_chunk_unlimited, sub_chunk, df_xlsx, threshold, output_dir, f"{chunk_index}_{sub_chunk_index}"
                    ))
            else:
                futures.append(executor.submit(
                    match_chunk_unlimited, chunk, df_xlsx, threshold, output_dir, chunk_index
                ))

        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing chunks"):
            temp_files.append(future.result())

    # Combine all temporary files into a single DataFrame
    combined_results = pd.concat([pd.read_parquet(temp_file) for temp_file in glob.glob(os.path.join(output_dir, "chunk_*.parquet"))], ignore_index=True)

    # Optionally, clean up temporary files
    # Uncomment the following lines if you want to delete temporary files after combining
    # for temp_file in glob.glob(os.path.join(output_dir, "chunk_*.parquet")):
    #     os.remove(temp_file)

    return combined_results

# Usage example
output_dir = os.path.join(data_path, 'temp_parquet')  # Directory to store intermediate results
matched_df = find_similar_nids_unlimited(
    df_unique_filtered, 
    df_xlsx, 
    threshold=95, 
    chunk_size=500, 
    output_dir=output_dir, 
    n_jobs=-1
)

# Save the final results
output_path = os.path.join(data_path, 'Matching/matched_rows.parquet')
matched_df.to_parquet(output_path, index=False)
# Out:
# Processing chunks: 100%|██████████| 4800/4800 [3:48:03<00:00,  2.85s/it]

# %%
def german_umlaut_replace(text):
    replacements = {
        'ä': 'ae', 'ö': 'oe', 'ü': 'ue',
        'Ä': 'Ae', 'Ö': 'Oe', 'Ü': 'Ue',
        'ß': 'ss'
    }
    for search, replace in replacements.items():
        text = text.replace(search, replace)
    return text

def preprocess_name(name):
    if not isinstance(name, str):
        return ''

    # Initial cleaning
    name = name.strip().lower()
    name = german_umlaut_replace(name)

    # Enhanced pattern removal - ordered from specific to general
    patterns = [
        # Legal forms with connectors (&/und) first
        r'ug\s*\(haftungsbeschraenkt\)\s*(?:und|\&)\s*co\.?\s*kg',
        r'ug\s*\(haftungsbeschraenkt\)',                   # 'UG (haftungsbeschränkt)'
        r'ug\s*haftungsbeschraenkt',                       # 'UG haftungsbeschränkt'
        r'gmbh\s*(?:und|\&)\s*co\.?\s*kg',
        
        # Standard legal forms (including full versions)
        r'gesellschaft\s+mit\s+beschraenkter\s+haftung',  # Full form
        r'gesellschaft\s+mbh',  # Full form'
        r'ges\.?\s*m\.?\s*b\.?\s*h\.?',                  # G.m.b.H. variations
        r'\(gmbh\)',                                     # (GmbH)
        r'\bgmbh\b',
        r'\bkg\b',
        r'\bohg\b',
        r'\bmbh\b',
        r'\bag\b',
        r'\be\.?k\.?\b',
        r'\bco\.?\b',
        
        # Other common legal terms
        r'kommanditgesellschaft',
        r'aktiengesellschaft',
        r'partnerschaft',
        r'verein\b',
        r'ev\b',  # eingetragener Verein
        r'eg\b',  # Europäische Genossenschaft
        r'se\b',  # Societas Europaea
        
        # General terms (catch-all at end)
        r'\bgesellschaft\b',
        r'\bund\b',
        r'\bco\b',
    ]

    for pattern in patterns:
        name = re.sub(pattern, '', name, flags=re.IGNORECASE)

    # Clean up results
    name = re.sub(r'[-/]', ' ', name)          # Replace hyphens/slashes with space
    name = re.sub(r'[^\w\s]', '', name)        # Remove special chars
    name = re.sub(r'\s+', ' ', name).strip()   # Normalize whitespace
    
    # Remove leftover connectors (like "&" becoming empty after removal)
    name = re.sub(r'\b(und|&)\b', '', name).strip()
    
    # Final cleanup if we have leftover "mit" from legal forms
    name = re.sub(r'\bmit\b', '', name).strip()
    
    return name

# %%
'''
# Function to preprocess names by removing specific substrings
def preprocess_name(name):
    # Convert to lowercase
    name = name.lower()
    # Remove special characters
    name = re.sub(r'[^\w\s]', '', name)
    # Normalize whitespace
    name = re.sub(r'\s+', ' ', name).strip()
    patterns = [
        r'\bGMBH\b',
        r'\bGMBH & CO\b',
        r'\bGMBH & CO\. KG\b',
        r'\bKOMMANDITGESELLSCHAFT\b',
        r'\b UG (HAFTUNGSBESCHRÄNKT)\b',
        r' AG$',
        r'\bAktiengesellschaft\b',
        r'\bGesellschaft mit beschränkter Haftung\b',
        r'\bsgesellschaft mbH & Co. KG\b',
        r'\bgesellschaft\b',
        r'\bgesellschaft für\b',
        r'\bmbhmbh\b'
    ]
    for pattern in patterns:
        name = re.sub(pattern, '', name, flags=re.IGNORECASE)
    return name.strip()
'''

# Function to calculate similarity ratio between two names
def is_similar(name1, name2):
    name1 = preprocess_name(name1)
    name2 = preprocess_name(name2)
    return fuzz.WRatio(name1, name2), fuzz.partial_token_sort_ratio(name1, name2)

# Function to process a chunk of the DataFrame
def process_chunk(chunk, threshold):
    results = []
    for _, row in chunk.iterrows():
        wratio, parttoksort_ratio = is_similar(row['Name of the beneficiary'], row['orbis_name'])
        if wratio >= threshold:
            row_with_ratio = row.copy()
            row_with_ratio['wratio'] = wratio
            row_with_ratio['parttoksort_ratio'] = parttoksort_ratio
            results.append(row_with_ratio)
    return results

# Function to process a single Parquet file
def process_parquet_file(parquet_path, output_path, threshold=70, chunk_size=1000):
    # Load the Parquet file
    df_match = pd.read_parquet(parquet_path)
    
    # Split the DataFrame into chunks
    chunks = [df_match.iloc[i:i + chunk_size] for i in range(0, len(df_match), chunk_size)]
    
    results = []
    with ProcessPoolExecutor() as executor:
        futures = {executor.submit(process_chunk, chunk, threshold): chunk for chunk in chunks}
        for future in tqdm(as_completed(futures), total=len(futures), desc=f"Processing {os.path.basename(parquet_path)}"):
            results.extend(future.result())
    
    # Combine all results into a single DataFrame
    df_match_with_ratios = pd.DataFrame(results)
    
    # If df_match_with_ratios is empty, skip further processing
    if df_match_with_ratios.empty:
        print(f"Skipping filtering for {parquet_path} as no matches were found.")
        return
    
    # Group by 'Ref-no.' and find the maximum 'wratio' for each group
    max_wratio = df_match_with_ratios.groupby('Ref-no.')['wratio'].max()
    df_match_with_ratios = df_match_with_ratios.merge(
        max_wratio.rename('maxwratio'),  # Rename to avoid column name conflict
        left_on='Ref-no.',
        right_index=True,
        how='left'
    )
    
    # Filter the DataFrame to keep only rows where 'wratio' equals 'max_wratio'
    df_match_wratio_filtered = df_match_with_ratios[df_match_with_ratios['wratio'] == df_match_with_ratios['maxwratio']].copy()
    df_match_wratio_filtered.drop('maxwratio', axis=1, inplace=True)
    
    # Group by 'Ref-no.' and find the maximum 'parttoksort_ratio' for each group
    max_ptsetratio = df_match_wratio_filtered.groupby('Ref-no.')['parttoksort_ratio'].max()
    df_match_wratio_filtered = df_match_wratio_filtered.merge(
        max_ptsetratio.rename('maxptsetratio'),  # Rename to avoid column name conflict
        left_on='Ref-no.',
        right_index=True,
        how='left'
    )
    
    # Filter the DataFrame to keep only rows where 'parttoksort_ratio' equals 'max_ptsetratio'
    df_filtered2ratio = df_match_wratio_filtered[df_match_wratio_filtered['parttoksort_ratio'] == df_match_wratio_filtered['maxptsetratio']].copy()
    df_filtered2ratio.drop('maxptsetratio', axis=1, inplace=True)
    
    # Save the filtered results to a Parquet file
    df_filtered2ratio.to_parquet(output_path, index=False)

# Main processing function
def process_all_parquet_files(parquet_dir, output_dir, final_output_path, threshold=70, chunk_size=1000):
    os.makedirs(output_dir, exist_ok=True)
    
    # Get a list of already processed files in `temp_match`
    processed_files = {os.path.splitext(f)[0] for f in os.listdir(output_dir) if f.endswith('.parquet')}
    
    # Process each Parquet file
    for parquet_file in tqdm(os.listdir(parquet_dir), desc="Processing Parquet files"):
        if parquet_file.endswith('.parquet'):
            # Check if the file has already been processed
            if os.path.splitext(parquet_file)[0] in processed_files:
                print(f"Skipping already processed file: {parquet_file}")
                continue
            
            parquet_path = os.path.join(parquet_dir, parquet_file)
            output_path = os.path.join(output_dir, parquet_file)
            
            # Load the Parquet file
            df_match = pd.read_parquet(parquet_path)
            
            # Skip empty files
            if df_match.empty:
                print(f"Skipping empty file: {parquet_file}")
                continue
            
            # Process the file
            process_parquet_file(parquet_path, output_path, threshold=threshold, chunk_size=chunk_size)
    
    # Merge all filtered Parquet files into a single Parquet file
    filtered_files = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if f.endswith('.parquet')]
    merged_df = pd.concat([pd.read_parquet(f) for f in filtered_files], ignore_index=True)
    merged_df.to_parquet(final_output_path, index=False)

# Directories
parquet_dir = os.path.join(data_path, 'temp_parquet')
output_dir = os.path.join(data_path, 'temp_match')
final_output_path = os.path.join(data_path, 'Matching/matched_rows_highestratio.parquet')

# Run the processing
process_all_parquet_files(parquet_dir, output_dir, final_output_path, threshold=70, chunk_size=50)

print(f"Filtered results saved to {final_output_path}")

# %%
# Save the final results
def ensure_consistent_types(df):
    """
    Ensure consistent data types for all columns in the DataFrame.
    """
    for column in df.columns:
        # If the column is numeric, convert it to float and ensure no mixed types
        if pd.api.types.is_numeric_dtype(df[column]):
            df[column] = pd.to_numeric(df[column], errors='coerce').astype(float)
        # If the column is not numeric, convert it to string
        else:
            df[column] = df[column].astype(str)
    return df

def merge_and_save_parquet(parquet_dir, output_path):
    """
    Merge all Parquet files in a directory, ensure consistent types, and save as a single Parquet file.
    """
    # List all Parquet files in the directory
    parquet_files = [os.path.join(parquet_dir, f) for f in os.listdir(parquet_dir) if f.endswith('.parquet')]

    # Initialize an empty list to store DataFrames
    dataframes = []

    # Read and process each Parquet file
    for file in parquet_files:
        print(f"Processing file: {file}")
        df = pd.read_parquet(file)
        # Ensure consistent types and handle mixed types explicitly
        df = ensure_consistent_types(df)
        # Convert 'nidscore' column to float explicitly if it exists
        if 'nidscore' in df.columns:
            df['nidscore'] = pd.to_numeric(df['nidscore'], errors='coerce')
        dataframes.append(df)

    # Concatenate all DataFrames
    merged_df = pd.concat(dataframes, ignore_index=True)

    # Save the merged DataFrame as a Parquet file
    merged_df.to_parquet(output_path, index=False)
    print(f"Merged Parquet file saved at: {output_path}")

# Define the input and output paths
parquet_dir = os.path.join(data_path, 'temp_match')  # Directory containing the Parquet files
output_path = os.path.join(data_path, 'Matching/matched_rows_highestratio.parquet')  # Output file path

# Run the merging and saving process
merge_and_save_parquet(parquet_dir, output_path)
# Out:
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_27.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_30.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_28.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_29.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_31.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_33.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_34.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_35.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_32.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_36.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_39.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_37.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_38.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_40.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_41.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_43.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_42.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_44.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_45.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_46.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_47.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_48.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_49.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_51.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_50.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_53.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_56.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_54.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_52.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_55.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_57.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_58.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_59.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_60.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_61.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_62.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_64.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_63.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_65.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_66.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_67.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_69.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_68.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_71.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_72.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_70.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_73.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_74.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_75.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_76.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_77.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_78.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_79.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_80.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_81.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_82.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_84.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_83.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_86.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_85.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_87.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_88.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_89.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_90.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_91.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_92.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_94.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_93.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_98.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_99.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_97.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_104.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_95.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_101.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_96.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_105.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_100.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_106.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_102.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_107.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_103.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_108.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_109.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_110.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_113.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_114.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_115.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_112.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_117.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_121.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_123.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_122.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_120.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_119.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_124.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_125.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_126.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_111.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_116.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_127.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_129.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_128.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_130.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_131.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_132.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_135.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_133.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_136.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_134.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_137.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_138.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_139.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_140.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_141.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_142.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_144.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_143.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_145.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_154.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_151.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_147.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_148.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_153.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_149.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_150.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_152.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_155.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_146.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_156.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_157.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_158.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_159.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_160.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_163.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_161.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_165.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_164.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_162.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_168.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_167.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_166.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_169.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_174.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_176.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_173.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_175.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_184.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_180.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_182.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_177.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_170.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_172.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_183.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_179.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_171.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_178.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_181.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_192.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_193.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_194.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_187.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_185.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_188.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_189.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_186.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_190.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_191.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_197.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_195.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_196.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_199.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_202.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_203.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_201.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_200.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_204.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_212.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_208.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_209.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_210.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_206.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_205.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_207.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_213.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_211.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_198.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_223.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_220.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_0.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_1.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_2.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_3.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_4.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_5.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_6.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_7.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_8.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_9.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_10.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_11.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_12.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_13.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_14.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_18.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_27.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_28.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_29.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_34.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_30.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_32.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_33.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_35.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_31.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_48.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_49.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_37.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_39.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_40.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_41.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_42.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_36.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_47.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_38.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_43.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_45.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_46.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_118_44.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_221.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_225.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_218.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_216.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_219.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_224.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_227.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_226.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_214.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_217.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_222.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_228.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_229.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_230.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_231.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_0.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_1.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_2.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_3.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_4.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_5.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_6.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_7.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_8.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_9.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_10.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_11.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_13.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_12.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_14.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_18.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_34.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_35.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_36.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_28.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_38.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_42.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_27.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_43.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_44.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_29.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_46.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_47.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_32.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_48.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_49.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_30.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_31.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_33.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_215_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_0.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_1.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_2.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_3.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_4.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_5.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_6.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_7.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_8.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_9.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_10.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_11.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_12.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_13.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_14.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_18.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_27.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_28.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_29.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_30.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_31.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_32.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_33.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_34.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_35.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_36.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_37.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_38.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_39.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_40.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_41.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_42.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_43.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_44.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_45.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_46.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_47.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_48.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_232_49.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_0.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_1.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_2.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_3.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_4.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_5.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_6.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_7.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_8.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_9.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_10.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_11.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_12.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_13.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_14.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_18.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_233_27.parquet
# ...
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_61.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_62.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_63.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_64.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_65.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_66.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_67.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_68.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_69.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_70.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_71.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_72.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_73.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_74.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_75.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_76.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_77.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_78.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_79.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_80.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_81.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_82.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_83.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_84.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_85.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_86.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_87.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_88.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_89.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_90.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_91.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_92.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_93.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_94.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_95.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_96.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_97.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_98.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_287_99.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_0.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_1.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_2.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_3.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_4.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_5.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_6.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_7.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_8.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_9.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_10.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_11.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_12.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_13.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_14.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_15.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_16.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_17.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_18.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_19.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_20.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_21.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_22.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_23.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_24.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_25.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_26.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_27.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_28.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_29.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_30.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_31.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_32.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_33.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_34.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_35.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_36.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_37.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_38.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_39.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_40.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_41.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_42.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_43.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_44.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_45.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_46.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_47.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_48.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_49.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_50.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_51.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_52.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_53.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_54.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_55.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_56.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_57.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_58.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_59.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_60.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_61.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_62.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_63.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_64.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_65.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_66.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_67.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_68.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_69.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_70.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_71.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_72.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_73.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_74.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_75.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_76.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_77.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_78.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_79.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_80.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_81.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_82.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_83.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_84.parquet
# Processing file: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/temp_match/chunk_288_85.parquet
# Merged Parquet file saved at: /var/home/econmeownist/Documents/IMT-Lucca/Policy-Learning/StateAid/Data/GER/Matching/matched_rows_highestratio.parquet

# %%
df = pd.read_parquet(os.path.join(data_path, 'Matching/matched_rows_highestratio.parquet'))
df_test = df[df['parttoksort_ratio'] >= 70].copy()

# %%
df_dup = df_test[df_test.duplicated(subset=['National ID', 'Name of the beneficiary'], keep=False)].copy()
df_dup_filtered = df_dup[
    (~df_dup['National ID'].isin(['nan', 'n.a.' ,'', np.nan, None])) & 
    (~df_dup['Name of the beneficiary'].isin(['nan', '', np.nan, None]))
].copy()

# %%
'''
# Group by 'Name of the beneficiary' and count the number of duplicates
duplicate_counts = df_dup_filtered.groupby('Name of the beneficiary').size().reset_index(name='Duplicate Count')

# Sort the results by the 'Duplicate Count' column in descending order
top_duplicates = duplicate_counts.sort_values(by='Duplicate Count', ascending=False).head(10)

# Display the top 10 entries with the most duplicates
print(top_duplicates)
'''
# Out:
#         Name of the beneficiary  Duplicate Count
# 283                   LADE GmbH              383
# 33      AUDI Aktiengesellschaft              382
# 101              Canan Demircan               34
# 380             Region Hannover               32
# 422  Siemens Aktiengesellschaft               26
# 45             Anan Asia Imbiss               26
# 342      PIPE Kenan Nuradinovic               23
# 266           Kakar & Anand GbR               23
# 381       Reisebüro Canan Hecht               23
# 454   Stotzem Food Service Gmbh               22

# %%
df_dup_filtered = df_dup_filtered[~df_dup_filtered['Name of the beneficiary'].isin([
    'LADE GmbH',
    'AUDI Aktiengesellschaft'
])]

# %%
df_dup_filtered

# %%
df_dup_filtered = df_dup_filtered[df_dup_filtered['wratio'] >= 90].copy()

# %%
df_bvdid = df_dup_filtered['bvd_id']
# Export
df_bvdid.to_csv(os.path.join(data_path, 'Matching/bvd_id_fororbis_date.csv'), index=False, header=True)

# %%
df_unchanged_bvd = pd.read_excel(os.path.join(data_path, 'Matching/Unchanged_BvDID.xlsx'), sheet_name='Results')
df_unchanged_bvd.rename(columns={'BvD ID number': 'bvd_id'}, inplace=True)
df_dup_filtered['Unchanged'] = df_dup_filtered['bvd_id'].isin(df_unchanged_bvd['bvd_id'])

df_dup_filtered = df_dup_filtered.merge(
    df_unchanged_bvd[['bvd_id', 'Last avail. year']],
    on='bvd_id',  # Use 'on' since both DataFrames now have the same column name
    how='left',
)

# Group by 'National ID' and 'Name of the beneficiary' and keep the row with the highest 'Last avail. year'
df_highest_year = df_dup_filtered.loc[
    df_dup_filtered.groupby(['National ID', 'Name of the beneficiary'])['Last avail. year'].idxmax()
]

# Reset the index for the resulting DataFrame
df_highest_year = df_highest_year.reset_index(drop=True)

# %%
# Add a new column to store user input
df_highest_year['similar'] = None

# Iterate through each row in the DataFrame
for index, row in df_highest_year.iterrows():
    # Print the names for comparison
    print(f"Name of the beneficiary: {row['Name of the beneficiary']}")
    print(f"Orbis name: {row['orbis_name']}")
    
    # Ask for user input
    user_input = input("Do you find the names similar? (y/n): ").strip().lower()
    
    # Validate input
    while user_input not in ['y', 'n']:
        print("Invalid input. Please enter 'y' for yes or 'n' for no.")
        user_input = input("Do you find the names similar? (y/n): ").strip().lower()
    
    # Append the input to the 'similar' column
    df_highest_year.at[index, 'similar'] = user_input

# Drop rows where the 'similar' column has 'n'
#df_highest_year = df_highest_year[df_highest_year['similar'] != 'n']

# Drop the 'similar' column if you no longer need it
#df_highest_year.drop(columns=['manual_similar'], inplace=True)

# Display the filtered DataFrame
print("Filtered DataFrame:")
print(df_highest_year)

#export
df_highest_year.to_parquet(os.path.join(data_path, 'Matching/matched_dup_filtered.parquet'), index=False)
# Out:
# Name of the beneficiary: Hotel Diedrich OHG
# Orbis name: HOTEL DIEDRICH OHG
# Name of the beneficiary: Gut Gransebieth GmbH & Co. KG
# Orbis name: UT GMBH
# Name of the beneficiary: Fa. Brunhilde Berlage
# Orbis name: RUN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schulzek Ewald GmbH
# Orbis name: EWALD SCHULZEK GMBH
# Name of the beneficiary: Hotel Diedrich OHG
# Orbis name: HOTEL DIEDRICH OHG
# Name of the beneficiary: Agrargenossenschaft Roland Buch eG
# Orbis name: AGRAR EG
# Name of the beneficiary: Schmitz Catering GmbH
# Orbis name: SCHMITZ - CATERING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Adnan Oral
# Orbis name: RASE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: GHF Glashütte Freital GmbH
# Orbis name: GHF GLASHÜTTE FREITAL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Anan Asia Imbiss
# Orbis name: MBI GMBH
# Name of the beneficiary: Feines von Legrum Catering & Manufaktur GmbH
# Orbis name: FEINES VON LEGRUM CATERING & MANUFAKTUR GMBH
# Name of the beneficiary: Canan Demircan
# Orbis name: I+R GMBH
# Name of the beneficiary: Canan Ulusoy
# Orbis name: U+S GMBH
# Name of the beneficiary: Bundesanstalt für Gewässerkunde (BfG)
# Orbis name: ER & GE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Bundesanstalt für Wasserbau
# Orbis name: ERBA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Deutscher Wetterdienst (DWD)
# Orbis name: WETTER & CO. GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LVM - Landesverband  Metall
# Orbis name: ERBA GMBH
# Name of the beneficiary: Pfeiffersche Siftungen Magdeburg
# Orbis name: FERSCH GMBH & CO KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stadt Flensburg
# Orbis name: ENSEV GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: A1 Digital Deutschland GmbH
# Orbis name: TSC GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Aalberts Surface Technologies GmbH
# Orbis name: AALBERTS SURFACE TECHNOLOGIES GMBH
# Name of the beneficiary: Bechtle Aktiengesellschaft
# Orbis name: BECHTLE GMBH & CO.KG
# Name of the beneficiary: Boutiquehotel Ochsen GmbH
# Orbis name: SEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: COMTRONIC GmbH Verbindungstechnik
# Orbis name: GSTECH GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: CorTec GmbH
# Orbis name: CORTEC GMBH
# Name of the beneficiary: DEKRA Digital GmbH
# Orbis name: RASE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Dr. Brockhaus-Meßtechnik GmbH & Co.
# Orbis name: BROCK GMBH.
# Name of the beneficiary: EvoBus GmbH
# Orbis name: OEV GMBH
# Name of the beneficiary: F.X. Schmid Metallbau & Schlosserei
# Orbis name: SCHMID GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Gartencenter Röhm GmbH
# Orbis name: R & R GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Heraeus Electronics GmbH & Co. KG
# Orbis name: ERA GMBH & CO. KG
# Name of the beneficiary: Hubject GmbH
# Orbis name: UBEG GMBH & CO. KG
# Name of the beneficiary: IPROconsult GmbH
# Orbis name: PROCON GMBH
# Name of the beneficiary: Intelligent Energy System Services GmbH
# Orbis name: EG. SERVICE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Jaeschke Holding GmbH
# Orbis name: ESC GMBH & CO. KG
# Name of the beneficiary: KAEMI GmbH
# Orbis name: ASE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: MAHLE chargeBIG GmbH
# Orbis name: AH GMBH
# Name of the beneficiary: Marquardt GmbH
# Orbis name: "MARQUARDT GMBH"
# Name of the beneficiary: Neosid Pemetzrieder GmbH & Co. KG
# Orbis name: EDER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Pionix GmbH
# Orbis name: ONIX GMBH & CO.KG
# Name of the beneficiary: REFINIO GmbH
# Orbis name: IEG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: REFU Drive GmbH
# Orbis name: VE GMBH
# Name of the beneficiary: RIB Information Technologies AG
# Orbis name: INFORMA GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schaeffler Technologies AG & Co. KG
# Orbis name: SCHAEFFLER TECHNOLOGIES AG & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Siemens Aktiengesellschaft
# Orbis name: ENSEV GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: So geht's Holding GmbH
# Orbis name: HTS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Software Aktiengesellschaft
# Orbis name: AS-SOFTWARE-GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SpaceNet AG
# Orbis name: ENE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stackable GmbH
# Orbis name: STA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stromnetz Hamburg GmbH
# Orbis name: AMBU GMBH
# Name of the beneficiary: TDK-Micronas GmbH
# Orbis name: ROSE GMBH & CO KG
# Name of the beneficiary: TrueOcean GmbH
# Orbis name: CE + CO GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Vilua Healthcare GmbH
# Orbis name: EAL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Waldbad Isny GmbH & Co. KG
# Orbis name: IS GMBH
# Name of the beneficiary: X-Spectrum GmbH
# Orbis name: SPECTRUM E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: XP Steffen Metallbau GmbH
# Orbis name: AG METALL GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: albis-elcon system Germany GmbH
# Orbis name: GERMA GMBH
# Name of the beneficiary: chargeIQ GmbH
# Orbis name: EI.Q. GMBH
# Name of the beneficiary: coneva GmbH
# Orbis name: ASE GMBH
# Name of the beneficiary: elexon GmbH
# Orbis name: OEV GMBH
# Name of the beneficiary: hySOLUTIONS GmbH
# Orbis name: S.O.!LUTIONS GMBH
# Name of the beneficiary: smartino Betriebs GmbH
# Orbis name: S.M.A. GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: smartlab Innovationsgesellschaft mbH
# Orbis name: INNOVATIO GMBH
# Name of the beneficiary: univention GmbH
# Orbis name: VE GMBH
# Name of the beneficiary: RWTH Aachen
# Orbis name: COMPUTER-CLUB AN DER RWTH AACHEN
# Name of the beneficiary: Tannenhof
# Orbis name: TANNENHOF MANAGEMENT GMBH
# Name of the beneficiary: zero one film GmbH
# Orbis name: ZERO ONE FILM GMBH
# Name of the beneficiary: Con
# Orbis name: CONSTANTIN FILM AG
# Name of the beneficiary: Schmalhofer M�hle e.K.
# Orbis name: SCHMALHOFER MÜHLE E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stiegeler Internet Service GmbH
# Orbis name: STIEGELER INTERNET SERVICE GMBH
# Name of the beneficiary: Der Eventmacher T + M GmbH
# Orbis name: DER EVENTMACHER T + M GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: MAN Financial Services, Zweigniederlassung der Volkswagen Leasing GmbH
# Orbis name: VOLKSWAGEN LEASING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FRIMO GmbH
# Orbis name: FRIMO GROUP GMBH
# Name of the beneficiary: Vodafone GmbH
# Orbis name: VODAFONE CUSTOMER CARE GMBH
# Name of the beneficiary: Hotel an der Multifunktionsarena Düsseldorf Betriebsgesellschaft mbH
# Orbis name: HOTEL AN DER MULTIFUNKTIONSARENA DÜSSELDORF BETRIEBSGESELLSCHAFT MBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Papierfabrik Adolf Jass GmbH & Co. KG
# Orbis name: PAPIERFABRIK ADOLF JASS GMBH
# Name of the beneficiary: Papierfabrik Adolf Jass GmbH & Co. Kg
# Orbis name: PAPIERFABRIK ADOLF JASS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Vogelsberger Basaltwerk GmbH & Co. KG
# Orbis name: VOGELSBERGER BASALTWERK GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Oschatz Visuelle Medien GmbH & Co. KG
# Orbis name: OSCHATZ VISUELLE MEDIEN GMBH
# Name of the beneficiary: Deutsche Bank AG
# Orbis name: DEUTSCHE BANK AG
# Name of the beneficiary: Baader Bank AG
# Orbis name: BAADER BANK AG
# Name of the beneficiary: Deutsche Börse AG
# Orbis name: DEUTSCHE BÖRSE AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Tradecom GmbH
# Orbis name: TRADECOM SERVICE GMBH
# Name of the beneficiary: Azul-Kaffee GmbH & Co. KG
# Orbis name: AZUL-KAFFEE GMBH & CO. KOMMANDITGESELLSCHAFT
# Name of the beneficiary: Nordzucker AG
# Orbis name: NORDZUCKER GMBH & CO. KG
# Name of the beneficiary: Wiesensee GmbH & Co. KG
# Orbis name: WIESENSEE VERWALTUNGS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hannoversche Volksbank eG
# Orbis name: HANNOVERSCHE VOLKSBANK EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Meisterbäckerei Steinecke GmbH & Co. KG
# Orbis name: MEISTERBÄCKEREI STEINECKE GMBH & CO. KG
# Name of the beneficiary: Stadtsparkasse Essen
# Orbis name: STADTSPARKASSE ESSEN
# Name of the beneficiary: RAG Aktiengesellschaft
# Orbis name: RAG AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: GEB Schuh-Großeinkaufs-Bund GmbH & Co. Kommanditgesellschaft
# Orbis name: GEB SCHUH-GROßEINKAUFS-BUND GMBH
# Name of the beneficiary: Volksbank Kleverland eG
# Orbis name: VOLKSBANK KLEVERLAND EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Rhein-Maas
# Orbis name: SPARKASSE RHEIN-MAAS
# Name of the beneficiary: ALDI SE & Co. KG Mönchengladbach
# Orbis name: ALDI SE & CO KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Kerpen
# Orbis name: ALDI SE & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Mörfelden-Walldorf
# Orbis name: ALDI SE & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Bous
# Orbis name: ALDI BOUS VERWALTUNGS-SE
# Name of the beneficiary: ALDI SE & Co. KG Aichtal
# Orbis name: ALDI AICHTAL VERWALTUNGS-SE
# Name of the beneficiary: ALDI SE & Co. KG Donaueschingen
# Orbis name: ALDI DONAUESCHINGEN VERWALTUNGS-SE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Ebersberg
# Orbis name: ALDI EBERSBERG VERWALTUNGS-SE
# Name of the beneficiary: ALDI SE & Co. KG Regenstauf
# Orbis name: ALDI SE & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Langenfeld
# Orbis name: ALDI SE & CO. KOMMANDITGESELLSCHAFT
# Name of the beneficiary: ALDI SE & Co. KG Adelsdorf
# Orbis name: ALDI SE & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Bingen
# Orbis name: ALDI BINGEN VERWALTUNGS-SE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stadtsparkasse Wuppertal
# Orbis name: STADTSPARKASSE WUPPERTAL
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: B u. B Parkhaus GmbH & Co. Kommanditgesellschaft
# Orbis name: B + B PARKHAUS GMBH & CO. KOMMANDITGESELLSCHAFT
# Name of the beneficiary: B+B Parkhaus GmbH & Co. Kommanditgesellschaft
# Orbis name: B + B PARKHAUS GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Generali Deutschland AG
# Orbis name: GENERALI DEUTSCHLAND AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Albert Hoffmann GmbH
# Orbis name: ALBERT HOFFMANN GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: P.J. Hövel GmbH & Co. KG
# Orbis name: P. J. HÖVEL GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Gronauer Tannenhof Hotel-Restaurant-Café GmbH & Co. KG
# Orbis name: GRONAUER TANNENHOF HOTEL-RESTAURANT-CAFÉ GMBH & CO. KG
# Name of the beneficiary: Roland Rechtsschutz-Versicherungs-AG
# Orbis name: ROLAND RECHTSSCHUTZ-VERSICHERUNGS-AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Buchhandlung Walther König GmbH & Co. KG
# Orbis name: BUCHHANDLUNG WALTHER KÖNIG GMBH & CO KOMMANDITGESELLSCHAFT
# Name of the beneficiary: Egetürk GmbH & Co. KG
# Orbis name: EGETÜRK VERMÖGENSVERWALTUNGS-GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Emil Koch GmbH & Co. KG
# Orbis name: EMIL KOCH SCHALTANLAGEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: silver plastics GmbH & Co. KG
# Orbis name: SILVER-PLASTICS GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: silver plastics GmbH&Co KG
# Orbis name: SILVER-PLASTICS GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Fritz Schmidt Metallgiesserei GmbH & Co. KG
# Orbis name: FRITZ SCHMIDT METALLGIEßEREI GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Boulangerie Wolf GmbH
# Orbis name: BOULANGERIE WOLF GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Westmünsterland
# Orbis name: SPARKASSE WESTMÜNSTERLAND
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Volksbank Sauerland eG
# Orbis name: VOLKSBANK SAUERLAND EG
# Name of the beneficiary: Autohaus Brüggemann GmbH & Co. KG
# Orbis name: AUTOHAUS BRÜGGEMANN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Klostermann GmbH & Co. KG
# Orbis name: KLOSTERMANN SCHUTZSYSTEME GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: XTRAFIT GmbH
# Orbis name: XTRAFIT GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Wilhelm Rehage KG
# Orbis name: WILHELM REHAGE KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Windmöller und Hölscher KG
# Orbis name: WINDMÖLLER & HÖLSCHER, GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Lemgo
# Orbis name: SPARKASSE LEMGO
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schramm GmbH & Co. KG
# Orbis name: SCHRAMM GMBH
# Name of the beneficiary: OTTO FUCHS Kommanditgesellschaft
# Orbis name: OTTO FUCHS SURFACE TECHNOLOGY GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schuhhaus Hch. Zumnorde GmbH & Co. KG
# Orbis name: SCHUHHAUS HCH. ZUMNORDE GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Koffer-Kopf e.K.
# Orbis name: KOFFER-KOPF, INH. JÜRGEN FALLER
# Name of the beneficiary: Ziegelwerk Stengel GmbH
# Orbis name: ZIEGELWERK STENGEL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Ziegelwerk Stengel GmbH & Co. KG
# Orbis name: ZIEGELWERK STENGEL GMBH
# Name of the beneficiary: Wilhelm Geiger GmbH & Co. KG
# Orbis name: WILHELM GEIGER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VR-Bank Landsberg-Ammersee eG
# Orbis name: VR-BANK LANDSBERG-AMMERSEE EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stadtsparkasse München
# Orbis name: STADTSPARKASSE MÜNCHEN
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: UniCredit Bank GmbH
# Orbis name: UNICREDIT BANK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BMW AG
# Orbis name: BMW INTEC BETEILIGUNGS GMBH
# Name of the beneficiary: Hirmer GmbH & Co. KG
# Orbis name: HIRMER GMBH & CO. KG
# Name of the beneficiary: Max Frank GmbH & Co. KG
# Orbis name: MAX FRANK GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Name of the beneficiary: VR-Bank Mittelfranken Mitte eG
# Orbis name: VR-BANK MITTELFRANKEN MITTE EG
# Name of the beneficiary: Gartenwelt Dauchenbeck e.K.
# Orbis name: GARTENWELT DAUCHENBECK GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Fürth
# Orbis name: SPARKASSE FÜRTH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VR Bank Bayreuth-Hof eG
# Orbis name: VR BANK BAYREUTH-HOF EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KLEBL GmbH Rinteln
# Orbis name: KLEBL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Bayernland eG
# Orbis name: BAYERNLAND EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparda-Bank Ostbayern eG
# Orbis name: SPARDA-BANK OSTBAYERN EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Köberlein & Seigert GmbH
# Orbis name: KÖBERLEIN & SEIGERT GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: A.T.U Auto-Teile-Unger GmbH & Co. KG
# Orbis name: A.T.U AUTO-TEILE-UNGER GMBH & CO. KG
# Name of the beneficiary: WEISSENBURG Industrie-Technik
# Orbis name: WEISSENBURG INDUSTRIE- TECHNIK MASCHINENBAU GMBH
# Name of the beneficiary: WEISSENBURG Inustrie-Technik Maschinenbau GmbH & Co. KG
# Orbis name: WEISSENBURG INDUSTRIE- TECHNIK MASCHINENBAU GMBH
# Name of the beneficiary: Kraushaar Ferienwohnungen
# Orbis name: KRAUSHAAR FERIENWOHNUNGEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Vereinigte Asphalt Mischwerke GmbH & Co KG
# Orbis name: VEREINIGTE ASPHALT-MISCHWERKE GMBH
# Name of the beneficiary: Deutsches Jugendherbergswerk
# Orbis name: DEUTSCHES JUGENDHERBERGSWERK - LANDESVERBAND BERLIN-BRANDENBURG E.V.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Deutsches Jugendherbergswerk - Landesverband Berlin - Brandenburg
# Orbis name: DEUTSCHES JUGENDHERBERGSWERK - LANDESVERBAND BERLIN-BRANDENBURG E.V.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hotel im Europa-Center Verwaltungsgesellschaft mbH & Co. KG
# Orbis name: HOTEL IM EUROPA-CENTER VERWALTUNGSGESELLSCHAFT MBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KKT GmbH - Kikis Kleiner Tourneeservice
# Orbis name: KKT GMBH - KIKIS KLEINER TOURNEESERVICE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Magdeburger Mühlenwerke GmbH
# Orbis name: MAGDEBURGER MÜHLENWERKE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Magdeburger M�hlenwerke GmbH
# Orbis name: MAGDEBURGER MÜHLENWERKE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stadtsparkasse Dessau
# Orbis name: STADTSPARKASSE DESSAU
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Kraichgau
# Orbis name: SPARKASSE KRAICHGAU BRUCHSAL-BRETTEN-SINSHEIM
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Karlsruhe
# Orbis name: SPARKASSE KARLSRUHE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Kreissparkasse Biberach
# Orbis name: KREISSPARKASSE BIBERACH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VR-Bank Ludwigsburg eG
# Orbis name: VR-BANK LUDWIGSBURG EG
# Name of the beneficiary: Ihre Volksbank eG   Neckar Odenwald Main Tauber
# Orbis name: IHRE VOLKSBANK EG NECKAR ODENWALD MAIN TAUBER
# Name of the beneficiary: Landesbank Baden-Württemberg
# Orbis name: LANDESBANK BADEN-WÜRTTEMBERG
# Name of the beneficiary: SV SparkassenVersicherung Lebensversicherung AG
# Orbis name: SV SPARKASSENVERSICHERUNG LEBENSVERSICHERUNG AKTIENGESELLSCHAFT
# Name of the beneficiary: Ruprecht Tretter Autohaus GmbH & Co. KG
# Orbis name: RUPRECHT TRETTER AUTOHAUS GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Rhein - Haardt
# Orbis name: SPARKASSE RHEIN-HAARDT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Mittelthüringen
# Orbis name: SPARKASSE MITTELTHÜRINGEN
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Art of Travel  GmbH
# Orbis name: ART OF TRAVEL GMBH
# Name of the beneficiary: Art of Travel GmbH
# Orbis name: ART OF TRAVEL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: UNI ELEKTRO Fachgroßhandel GmbH & Co. KG
# Orbis name: UNI ELEKTRO FACHGROßHANDEL GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Nußbaum Reisen GmbH & Co. KG
# Orbis name: NUßBAUM-REISEN OMNIBUS GMBH U. CO. KG
# Name of the beneficiary: für & mit GmbH & Co. KG
# Orbis name: FÜR&MIT GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SparkassenVersicherung Holding AG
# Orbis name: SV SPARKASSENVERSICHERUNG HOLDING AKTIENGESELLSCHAFT
# Name of the beneficiary: adapoe Event- und Studiotechnik OHG
# Orbis name: ADAPOE EVENT- UND STUDIOTECHNIK OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: zero one film GmbH
# Orbis name: ZERO ONE FILM GMBH
# Name of the beneficiary: Hotelbetriebe Becker
# Orbis name: HOTELBETRIEBE BECKER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hotelbetriebe Becker GmbH
# Orbis name: HOTELBETRIEBE BECKER GMBH
# Name of the beneficiary: Schloss Elmau GmbH & Co. KG
# Orbis name: SCHLOSS ELMAU GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Augustus Tours e.K.
# Orbis name: AUGUSTUSTOURS GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BVT Windpark Sustrum/Renkenberge GmbH & Co. KG
# Orbis name: BVT WINDPARK SUSTRUM/RENKENBERGE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BVT Windpark SustrumRenkenberge GmbH & Co. KG
# Orbis name: BVT WINDPARK SUSTRUM/RENKENBERGE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Bacio d'oro Schmuckvertriebs GmbH
# Orbis name: BACIO D'ORO SCHMUCKVERTRIEBS-GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Wüstenrot Bausparkasse AG
# Orbis name: WÜSTENROT BAUSPARKASSE AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Georgsmarienhütte GmbH
# Orbis name: GEORGSMARIENHÜTTE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Georgsmarienh�tte GmbH
# Orbis name: GEORGSMARIENHÜTTE GMBH
# Name of the beneficiary: Gosch Verwaltungs GmbH & Co. KG
# Orbis name: GOSCH VERWALTUNGS GMBH
# Name of the beneficiary: v. Beust & Partner GmbH & Co. KG
# Orbis name: V. BEUST & PARTNER GMBH & CO. KOMMANDTIGESELLSCHAFT AGENTUR FÜR LIVE KOMMUNIKATION
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: INTEC Industrie-Technik GmbH & Co. KG
# Orbis name: INTEC INDUSTRIE-TECHNIK GMBH
# Name of the beneficiary: Intec Industrie-Technik GmbH & Co. KG
# Orbis name: INTEC INDUSTRIE-TECHNIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Brandner KG
# Orbis name: BRANDNER UNTERALLGÄU KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Teddy Toys Kinderwelt GmbH
# Orbis name: TEDDY TOYS KINDERWELT GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VMG Vertriebs-Marketing-Gesellschaft mbH
# Orbis name: VMG,  VERTRIEBS-MARKETING- GESELLSCHAFT MBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VMG, Vertriebs-Marketing-Gesellschaft mbH
# Orbis name: VMG,  VERTRIEBS-MARKETING- GESELLSCHAFT MBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Real I.S. AG
# Orbis name: REAL I.S. INVESTMENT GMBH
# Name of the beneficiary: Nagy GmbH
# Orbis name: NAGY GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hamburger Sparkasse AG
# Orbis name: HAMBURGER SPARKASSE AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: MRK Media AG
# Orbis name: MRK MEDIA AG
# Name of the beneficiary: MRK Media AG;Tele-Kabel-Ingenieurgesellschaft mbH
# Orbis name: MRK MEDIA AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hoewelberend GmbH & Co.KG ( Alfons Hoewelberend jun)
# Orbis name: HÖWELBEREND GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Trendpool Schmuck GmbH
# Orbis name: TRENDPOOL SCHMUCK GMBH
# Name of the beneficiary: Hotel Esplanade Bad Saarow GmbH
# Orbis name: HOTEL ESPLANADE BAD SAAROW GMBH
# Name of the beneficiary: Fit 24 e. K. Inhaber Thomas Schießl
# Orbis name: FIT 24 E. K.
# Name of the beneficiary: Schmalhofer Mühle e.K.
# Orbis name: SCHMALHOFER MÜHLE E.K.
# Name of the beneficiary: Schmalhofer M�hle e.K.
# Orbis name: SCHMALHOFER MÜHLE E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: fonetastic GmbH & Co. KG
# Orbis name: FONETASTIC GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: S & D Systemgastronomie e.K.
# Orbis name: S&D SYSTEMGASTRONOMIE E.K.
# Name of the beneficiary: Aviation Investment GmbH
# Orbis name: AVIATION INVESTMENT GMBH
# Name of the beneficiary: FFP New Media GmbH
# Orbis name: FFP NEW MEDIA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Thomas Kendlinger e.K.
# Orbis name: GEBÄUDESERVICE THOMAS KENDLINGER E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hotel Wikingerhof GmbH & Co. KG
# Orbis name: HOTEL WIKINGERHOF GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Passion Mode GmbH
# Orbis name: "PASSION" MODE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Change of Scandinavia Germany
# Orbis name: CHANGE OF SCANDINAVIA GERMANY GMBH
# Name of the beneficiary: Voigt Seereisen Agentur GmbH
# Orbis name: VOIGT SEEREISEN-AGENTUR GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Altes Gymnasium GmbH & Co. KG
# Orbis name: ALTES GYMNASIUM HUSUM HOTEL GMBH
# Name of the beneficiary: Altes Gymnsium Husum Hotel GmbH & Co. KG
# Orbis name: ALTES GYMNASIUM HUSUM HOTEL GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Alpha Textildruck GmbH
# Orbis name: ALPHA TEXTILDRUCK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hüsges GmbH
# Orbis name: HÜSGES & SAHIN GMBH
# Name of the beneficiary: contzept GmbH & Co. KG
# Orbis name: CONTZEPT VERWALTUNGS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Budenzauber Betriebs- & Cateringgesellschaft mbH
# Orbis name: BUDENZAUBER BETRIEBS- UND CATERINGGESELLSCHAFT MBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Budenzauber Betriebs- und Cateringgesellschaft mbH
# Orbis name: BUDENZAUBER BETRIEBS- UND CATERINGGESELLSCHAFT MBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Prüftech GmbH
# Orbis name: PRÜFTECH GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Global Tech I Offshore Wind GmbH
# Orbis name: GLOBAL TECH I OFFSHORE WIND GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hotel Schlossweg GmbH
# Orbis name: HOTEL SCHLOSSWEG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Deutsches Jugendherbergswerk Landesverband Sachsen-Anhalt
# Orbis name: DEUTSCHES JUGENDHERBERGSWERK LANDESVERBAND SACHSEN-ANHALT E.V.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: epcan GmbH;MUENET GmbH & Co. KG
# Orbis name: MUENET GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Hotel an der Multifunktionsarena Düsseldorf Betriebsgesellschaft mbH
# Orbis name: HOTEL AN DER MULTIFUNKTIONSARENA DÜSSELDORF BETRIEBSGESELLSCHAFT MBH
# Name of the beneficiary: Klassik Garage GmbH & Co. KG
# Orbis name: KLASSIK GARAGE KRONBERG GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Klassik Garage GmbH & Co.KG
# Orbis name: KLASSIK GARAGE KRONBERG GMBH & CO. KG
# Name of the beneficiary: HD Wireless GmbH
# Orbis name: HD WIRELESS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Raffinerie Heide GmbH
# Orbis name: RAFFINERIE HEIDE GMBH
# Name of the beneficiary: HAPPYCAR GmbH
# Orbis name: HAPPYCAR GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Happycar GmbH
# Orbis name: HAPPYCAR GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Niklas Jost  e.K.
# Orbis name: NIKLAS JOST E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LISL GmbH & Co KG
# Orbis name: LISL LONG ISLAND SUMMER LOUNGE GMBH & CO. KG
# Name of the beneficiary: mekka events logistic OHG
# Orbis name: MEKKA EVENTS LOGISTIC OHG
# Name of the beneficiary: TopClean GmbH & Co. KG
# Orbis name: TOPCLEAN VERWALTUNGS GMBH
# Name of the beneficiary: TopClean GmbH Co. KG
# Orbis name: TOPCLEAN VERWALTUNGS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Topclean
# Orbis name: TOPCLEAN VERWALTUNGS GMBH
# Name of the beneficiary: Geschmackslabor
# Orbis name: GESCHMACKSLABOR EVENT & CATERING - K. SOYTÜRK E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: geschmackslabor event & catering
# Orbis name: GESCHMACKSLABOR EVENT & CATERING - K. SOYTÜRK E.K.
# Name of the beneficiary: eifas GmbH
# Orbis name: EIFAS LICENSING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: TechnoGuss  GmbH
# Orbis name: TECHNOGUSS GMBH
# Name of the beneficiary: TechnoGuss GmbH
# Orbis name: TECHNOGUSS GMBH
# Name of the beneficiary: Bewerbergemeinschaft Stiegeler Internet Service GmbH und Stiegeler IT Systemhaus GmbH & Co. KG
# Orbis name: STIEGELER INTERNET SERVICE GMBH
# Name of the beneficiary: Stiegeler Internet Service GmbH & Co. KG
# Orbis name: STIEGELER INTERNET SERVICE GMBH
# Name of the beneficiary: Hotel Diedrich OHG
# Orbis name: HOTEL DIEDRICH OHG
# Name of the beneficiary: Aytac Bau GmbH;Osterich GmbH;RTH Rohr- und Tiefbau Hoya GmbH;TBG GmbH
# Orbis name: OSTERICH GMBH
# Name of the beneficiary: Arktis Tours e.K.
# Orbis name: ARKTIS TOURS GMBH & CO.KG
# Name of the beneficiary: RELEXA Hotel GmbH
# Orbis name: RELEXA HOTEL BELLEVUE HAMBURG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: RELEXA hotel GmbH
# Orbis name: RELEXA HOTEL BELLEVUE HAMBURG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Württembergische Versicherung AG
# Orbis name: WÜRTTEMBERGISCHE VERSICHERUNG AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Württembergische Lebensversicherung Aktiengesellschaft
# Orbis name: WÜRTTEMBERGISCHE LEBENSVERSICHERUNG AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: DZ HYP AG
# Orbis name: DZ HYP AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Generali Deutschland Versicherung AG
# Orbis name: GENERALI DEUTSCHLAND VERSICHERUNG AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Polartherm Flachglas GmbH
# Orbis name: POLARTHERM-FLACHGLAS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Polartherm-Flachglas GmbH
# Orbis name: POLARTHERM-FLACHGLAS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Wüstenrot & Württembergische AG
# Orbis name: WÜSTENROT & WÜRTTEMBERGISCHE AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sonplas GmbH
# Orbis name: SONPLAS HOLDING GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BB Radio GmbH & Co. KG
# Orbis name: BB RADIO LÄNDERWELLE BERLIN/BRANDENBURG GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sparkasse Vorpommern
# Orbis name: SPARKASSE VORPOMMERN
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SV SparkassenVersicherung Gebäudeversicherung AG
# Orbis name: SV SPARKASSENVERSICHERUNG GEBÄUDEVERSICHERUNG AKTIENGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: aixit GmbH
# Orbis name: AIXIT GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LUTEC-System-Clamps GmbH
# Orbis name: LUTEC-SYSTEM-CLAMPS GMBH
# Name of the beneficiary: Puris
# Orbis name: PURIS BAD GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Möbel mit Zukunft GmbH
# Orbis name: MÖBEL MIT ZUKUNFT GMBH
# Name of the beneficiary: Vinnolit GmbH & Co. KG
# Orbis name: WESTLAKE VINNOLIT TREUHAND GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Clientfocus GmbH
# Orbis name: CLIENTFOCUS GMBH
# Name of the beneficiary: PUR Werner Palten GmbH
# Orbis name: PUR WERNER PALTEN GMBH
# Name of the beneficiary: Lidl Vertriebs-GmbH & Co. KG Großbeeren
# Orbis name: LIDL VERTRIEBS-GMBH & CO. KG
# Name of the beneficiary: Auto Levy GmbH & Co. KG
# Orbis name: AUTO LEVY GMBH
# Name of the beneficiary: Barthel GmbH & Co KG
# Orbis name: BARTHEL & ECKES BETEILIGUNGS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Dormagen
# Orbis name: ALDI DORMAGEN VERWALTUNGS-SE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALDI SE & Co. KG Butzbach
# Orbis name: ALDI BUTZBACH VERWALTUNGS-SE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Avangard Malz AG
# Orbis name: AVANGARD MALZ AG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Dorint GmbH
# Orbis name: DORINT BRAND VALUE GMBH
# Name of the beneficiary: chemcube GmbH
# Orbis name: CHEMCUBE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Ferdinando Amato
# Orbis name: INAN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Flavio Fernandes Duarte
# Orbis name: DES-CO UG (HAFTUNGSBESCHRÄNKT)
# Name of the beneficiary: FGS FLEISCHEREI- & GASTRONOMIE
# Orbis name: FGS FLEISCHEREI- & GASTRONOMIE-SERVICE BADEN EG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Region Hannover
# Orbis name: VE GMBH
# Name of the beneficiary: MSM Gruppe e.K.
# Orbis name: MS UG (HAFTUNGSBESCHRÄNKT) & CO. KG
# Name of the beneficiary: BHG
# Orbis name: BHG HANDELSZENTREN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: PIG Windpark Ohrte GmbH & Co. KG
# Orbis name: OHR GMBH & CO. KG
# Name of the beneficiary: HEIMATHAFEN GMBH & CO. KG
# Orbis name: HEIMATHAFEN GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: UNNASCH AND FRIENDS MESSEBAU G
# Orbis name: UNNASCH AND FRIENDS MESSEBAU  GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BiSa Gewerbegesellschaft mbH & Co. KG
# Orbis name: BISA GEWERBEGESELLSCHAFT MBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Energiepark  Hemelingen WP HEM GmbH & Co. KG
# Orbis name: ENERGIEPARK HEMELINGEN WP HEM GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: AUTOHAUS PISCHKE GMBH & CO. K
# Orbis name: AUTOHAUS PISCHKE GMBH & CO. KG
# Name of the beneficiary: TFT KRAFTTRAINING OHG
# Orbis name: TFT KRAFTTRAINING OHG
# Name of the beneficiary: Energie und Natur e.K.
# Orbis name: ENERGIE UND NATUR E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ZANSHIN DOJO GMBH & CO. KG
# Orbis name: ZANSHIN DOJO GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: THILO JANSSEN GMBH & CO. KG
# Orbis name: THILO JANßEN GMBH & CO. KG
# Name of the beneficiary: GEHRING-BUNTE GETRAENKE INDUST
# Orbis name: GEHRING - BUNTE GETRÄNKEINDUSTRIE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: AETERNUM SOLUTIONS GMBH & CO.K
# Orbis name: AETERNUM SOLUTIONS GMBH + CO.KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: STAHLBAU & ANARBEITUNGSCENTER
# Orbis name: STAHLBAU & ANARBEITUNGSCENTER HEIDEMANN GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Klinikum Landsberg/Lech
# Orbis name: KLINIKUM LANDSBERG AM LECH KU
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FEINFIX GMBH & CO. KG
# Orbis name: FEINFIX GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ZWEIRAD LIEBIG GMBH & CO. KG
# Orbis name: ZWEIRAD LIEBIG GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KLEI-HUES Betonbauteile GmbH & Co KG
# Orbis name: "KLEI-HUES" BETONBAUTEILE GMBH & CO. KG
# Name of the beneficiary: ENJOY FITNESS GMBH & CO. KG
# Orbis name: ENJOY FITNESS GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Gemüseanbau Niemöller GmbH & Co. KG
# Orbis name: GEMÜSEANBAU NIEMÖLLER GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BLUMEN GREIVING KG
# Orbis name: BLUMEN GREIVING KG
# Name of the beneficiary: SETZ FENSTER GMBH & CO.KG
# Orbis name: SETZ FENSTER GMBH & CO.KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LUNCHBOX CATERING GMBH & CO.KG
# Orbis name: LUNCHBOX CATERING GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: M.U.P. - CREATIVE WORKS OHG
# Orbis name: M. U. P. - CREATIVE WORKS OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Parkhotel Thale Betriebs GmbH
# Orbis name: PARKHOTEL THALE BETRIEBSGESELLSCHAFT MBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: PRAUSE HOLZBAUPLANUNG GMBH & C
# Orbis name: PRAUSE HOLZBAUPLANUNG GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SCHMITZWORLD GMBH & CO.KG
# Orbis name: SCHMITZWORLD GMBH & CO. KG
# Name of the beneficiary: NORD AUTOMOBILE TA GMBH & CO.
# Orbis name: NORD AUTOMOBILE TA GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SIGMA MEDIA POSTPRODUKTION  SE
# Orbis name: SIGMA MEDIA POSTPRODUKTION + SERVICES GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Z & L GMBH & CO. KG
# Orbis name: Z & L GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALFIPA GMBH & CO. KG
# Orbis name: ALFIPA GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: GETRAENKEGROSS- & EINZELHANDEL
# Orbis name: GETRÄNKEGROß- UND EINZELHANDEL QUAK OHG INH. STEFAN QUAK E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Buck GmbH & Co. KG
# Orbis name: BUCK GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Energiekontor Windkraft GmbH & Co. WP HOL KG
# Orbis name: ENERGIEKONTOR WINDKRAFT GMBH & CO. WP HOL KG
# Name of the beneficiary: H & D KLETTERWALD GMBH & CO.KG
# Orbis name: H & D KLETTERWALD GMBH & CO. KG
# Name of the beneficiary: RONDOGARD OHG
# Orbis name: RONDOGARD OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SCHLENGER STEUERBERATUNGSGESEL
# Orbis name: SCHLENGER STEUERBERATUNGSGESELLSCHAFT MBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: DARPDECADE GMBH & CO. KG
# Orbis name: DARPDECADE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Frank Flintrop e.K.
# Orbis name: FRANK FLINTROP E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: CHRIST ALEXANDER FRIEDRICH
# Orbis name: FRIEDRICH KOMMANDITGESELLSCHAFT
# Name of the beneficiary: Truthahnfarm Sambach Agrar KG
# Orbis name: TRUTHAHNFARM SAMBACH AGRAR KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KF-TRANSPORTE GMBH & CO. KG
# Orbis name: KF-TRANSPORTE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LIGNA ARTS OHG
# Orbis name: LIGNA ARTS OHG
# Name of the beneficiary: DEL-NORMALIEN GMBH & CO. KG
# Orbis name: DEL-NORMALIEN GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: MODULAP SYSTEMS GMBH & CO. KG
# Orbis name: MODULAP SYSTEMS GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BUSCH VERMOEGENS VERWALTUNGS G
# Orbis name: BUSCH VERMÖGENSVERWALTUNGS GMBH & CO. KG
# Name of the beneficiary: KAUSMANN FIDES E. K. RENé
# Orbis name: RENÉ KAUSMANN FIDES E. K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ORHAN OEZMAT E.KFM.
# Orbis name: ORHAN ÖZMAT E.KFM.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: WEICK CONSULTING GMBH + CO. KG
# Orbis name: WEICK CONSULTING GMBH + CO. KG
# Name of the beneficiary: BUERKLIN GMBH & CO. KG
# Orbis name: BÜRKLIN GMBH & CO. KG
# Name of the beneficiary: LAIB BUERSTEN GMBH & CO. KG
# Orbis name: LAIB BÜRSTEN GMBH & CO. KG
# Name of the beneficiary: ANTONS 4 GMBH & CO. KG
# Orbis name: ANTONS 4 GMBH & CO. KG
# Name of the beneficiary: SALOMON & FISCHER GMBH UND CO.
# Orbis name: SALOMON & FISCHER GMBH UND CO. OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Salomon & Fischer GmbH & Co. OHG
# Orbis name: SALOMON & FISCHER GMBH UND CO. OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KROmedia, Inhaber Thorsten Krommer
# Orbis name: KROMEDIA E.K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: HOTEL DIEDRICH OHG
# Orbis name: HOTEL DIEDRICH OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KAESE KOBER GMBH & CO. KG
# Orbis name: KÄSE KOBER GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Käse Kober GmbH & Co. KG
# Orbis name: KÄSE KOBER GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: THEUNISSEN WALTER
# Orbis name: WALTER THEUNISSEN E. KFM.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: VALENTIN SCHMITT GMBH & CO. KG
# Orbis name: VALENTIN SCHMITT GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ELSINGERS SCHEUNE GMBH & CO. K
# Orbis name: ELSINGERS SCHEUNE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ERNST BERGEMANN GMBH & CO. KG
# Orbis name: BERG OHG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: HUBER SANIERUNGSBETRIEB GMBH &
# Orbis name: HUBER SANIERUNGSBETRIEB GMBH & CO. KG
# Name of the beneficiary: Parkhotel Residenz GmbH & Co. KG
# Orbis name: PARKHOTEL RESIDENZ GMBH & CO. KG
# Name of the beneficiary: OEVENUMER BACKSTUBE GMBH & CO.
# Orbis name: OEVENUMER BACKSTUBE GMBH & CO. KG
# Name of the beneficiary: HPF GmbH & Co. KG
# Orbis name: HPF GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: TAUPITZ GmbH & Co. KG
# Orbis name: TAUPITZ GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schröder GmbH & Co. KG
# Orbis name: FRANZ SCHRÖDER GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Schröder GmbH & Co.KG
# Orbis name: FRANZ SCHRÖDER GMBH & CO. KOMMANDITGESELLSCHAFT
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Reisebüro Sander GmbH & Co. KG
# Orbis name: REISEBÜRO KATJA SANDER E.K.
# Name of the beneficiary: A&F Verwaltungs GmbH
# Orbis name: AF VERWALTUNGS GMBH
# Name of the beneficiary: BAYERNOIL Raffineriegesellschaft mbH
# Orbis name: FINE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Spieloase MV-VV GmbH
# Orbis name: MV GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Stotzem Food Service Gmbh
# Orbis name: EG. SERVICE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Tingan
# Orbis name: N&G UG (HAFTUNGSBESCHRÄNKT)
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: virtuelles Studio
# Orbis name: ELL GMBH
# ...
# Name of the beneficiary: KON SPEDITIONS GMBH
# Orbis name: KON SPEDITIONS GMBH
# Name of the beneficiary: YONNETZ GMBH
# Orbis name: YONNETZ GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BAVARIA-ZELTE GMBH
# Orbis name: BAVARIA-ZELTE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: DYWIDAG-Systems International GmbH
# Orbis name: DYWIDAG-SYSTEMS INTERNATIONAL GMBH
# Name of the beneficiary: ASPHALT-BAU CHEMNITZ ABC TIEF-
# Orbis name: ASPHALT-BAU CHEMNITZ ABC TIEF- UND STRAßENBAU GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ROTHENBURGER MARKTFRISCH VERAR
# Orbis name: MARK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: TA MONTAGEN GMBH
# Orbis name: TA MONTAGEN GMBH
# Name of the beneficiary: A & S INTENSIVFAHRSCHULE GMBH
# Orbis name: A & S INTENSIVFAHRSCHULE GMBH
# Name of the beneficiary: CAR-MEDIC GMBH KFZ-MEISTERBETR
# Orbis name: CAR-MEDIC GMBH KFZ-MEISTERBETRIEB
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Sympatex Technologies GmbH
# Orbis name: SYMPATEX TECHNOLOGIES GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: High Tech Corporate Services GmbH
# Orbis name: HIGH TECH CORPORATE SERVICES GMBH
# Name of the beneficiary: AMSilk GmbH
# Orbis name: AMSILK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ESTRICHVERLEGUNG STEPHAN GMBH
# Orbis name: ESTRICHVERLEGUNG STEPHAN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: BOHRMANN GESELLSCHAFT MIT BESC
# Orbis name: BOHRMANN GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Name of the beneficiary: BOHRMANN GMBH
# Orbis name: BOHRMANN GESELLSCHAFT MIT BESCHRÄNKTER HAFTUNG
# Name of the beneficiary: RiFlex GmbH Schlauchproduktion
# Orbis name: RIFLEX GMBH SCHLAUCHPRODUKTION
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Limata GmbH
# Orbis name: LIMATA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: INTERCOMP GREEN TECHNOLOGIES G
# Orbis name: INTERCOMP GREEN TECHNOLOGIES GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: AS-STORES GMBH
# Orbis name: AS-STORES GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Wintershall Holding GmbH
# Orbis name: ERS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FR. BREMER WEINHANDLUNG GMBH
# Orbis name: FR. BREMER WEINHANDLUNG GMBH
# Name of the beneficiary: MARSCHLER ENTWAESSERUNGSTECHNI
# Orbis name: MARSCHLER ENTWÄSSERUNGSTECHNIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: PREMIUM WHEELS GMBH
# Orbis name: PREMIUM WHEELS GMBH
# Name of the beneficiary: Grohnder Fährhaus GmbH
# Orbis name: GROHNDER FÄHRHAUS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: RMW GMBH, RHEIN MAIN WAREHOUSE
# Orbis name: RMW GMBH, RHEIN MAIN WAREHOUSE
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: CURUVIJA-AUSBAU GMBH
# Orbis name: CURUVIJA-AUSBAU GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FRANK POEKER GMBH
# Orbis name: FRANK PÖKER GMBH
# Name of the beneficiary: ASTORIA AUTOMOBILE GMBH
# Orbis name: ASTORIA AUTOMOBILE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LY-TEC GmbH
# Orbis name: LY-TEC GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Retsaurant Hanedan Bonn
# Orbis name: HANEDAN BONN GMBH
# Name of the beneficiary: STORCK BICYCLE GMBH
# Orbis name: STORCK BICYCLE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: EL KHAWAS TRADE GMBH
# Orbis name: EL KHAWAS TRADE GMBH
# Name of the beneficiary: Schock GmbH
# Orbis name: SCHOCK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KEMMLER ELECTRONIC GMBH
# Orbis name: KEMMLER ELECTRONIC GMBH
# Name of the beneficiary: FEINES VON LEGRUM CATERING & M
# Orbis name: FEINES VON LEGRUM CATERING & MANUFAKTUR GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ANDRES DRUCK + WERBUNG GMBH
# Orbis name: ANDRES DRUCK + WERBUNG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FENSTERFREUDE GMBH
# Orbis name: FENSTERFREUDE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: POWER PEOPLE GMBH
# Orbis name: POWER PEOPLE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: PI-CONCEPT GMBH
# Orbis name: PI-CONCEPT GMBH
# Name of the beneficiary: Kranken- und Pflegeanstalt Arenberg GmbH
# Orbis name: KRANKEN-UND PFLEGE-ANSTALT ARENBERG, GMBH
# Name of the beneficiary: ROTHE BAUTENSCHUTZ GMBH ERIC
# Orbis name: ERIC ROTHE BAUTENSCHUTZ GMBH
# Name of the beneficiary: HILMER VERMOEGENSVERWALTUNG GM
# Orbis name: HILMER VERMÖGENSVERWALTUNG GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: FENSTERTECHNIK BRAND GMBH
# Orbis name: FENSTERTECHNIK BRAND GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ASSKEA GMBH
# Orbis name: ASSKEA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Textildruckerei Lunzenau GmbH
# Orbis name: TEXTILDRUCKEREI LUNZENAU GMBH
# Name of the beneficiary: FAHRRAD ROSSKOPP GMBH
# Orbis name: FAHRRAD ROSSKOPP GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: HASICEVIC STAHLBAU GMBH
# Orbis name: HASICEVIC STAHLBAU GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: CONBOOK MEDIEN GMBH
# Orbis name: CONBOOK MEDIEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: INGENIEURBUERO MARQUARD GMBH
# Orbis name: INGENIEURBÜRO MARQUARD GMBH
# Name of the beneficiary: MEDIATECHNIK BAUM GMBH
# Orbis name: MEDIATECHNIK BAUM GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: WLA Software GmbH
# Orbis name: WLA SOFTWARE GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: KB PRUEFTECHNIK GMBH
# Orbis name: KB PRÜFTECHNIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: EDI GmbH
# Orbis name: OBSTKISTE GEDIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: S & G ZERSPANUNGSTECHNIK GMBH
# Orbis name: S & G ZERSPANUNGSTECHNIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Wittenstein SE
# Orbis name: WITTENSTEIN CYBER MOTOR GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: C& G GMBH TRADE SOLUTIONS
# Orbis name: C & G GMBH TRADE SOLUTIONS
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALEX STROEBER GMBH
# Orbis name: ALEX STRÖBER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Communal FM GmbH
# Orbis name: COMMUNAL-FM GMBH
# Name of the beneficiary: QUALITY ANALYSIS GMBH
# Orbis name: QUALITY ANALYSIS GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: THS SHISHA-BEDARF GMBH
# Orbis name: THS SHISHA-BEDARF GMBH
# Name of the beneficiary: HEBENSTREIT  METALDECORATING G
# Orbis name: HEBENSTREIT METAL DECORATING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: HEBENSTREIT METAL DECORATING G
# Orbis name: HEBENSTREIT METAL DECORATING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: MEDICAL-JOBS 24 GMBH
# Orbis name: MEDICAL-JOBS 24 GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: TEKMANN BAUUNTERNEHMEN GMBH
# Orbis name: TEKMANN BAUUNTERNEHMEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SCHWAB PRAEZISION GMBH
# Orbis name: SCHWAB PRÄZISION GMBH
# Name of the beneficiary: HP Spectroscopy GmbH
# Orbis name: HP SPECTROSCOPY GMBH
# Name of the beneficiary: KLOSTERGARTEN PFULLINGEN GMBH
# Orbis name: KLOSTERGARTEN PFULLINGEN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: LAUER & WEISS GMBH
# Orbis name: LAUER & WEISS GMBH
# Name of the beneficiary: GLADIS - BUSCH GMBH
# Orbis name: GLADIS - BUSCH GMBH
# Name of the beneficiary: POS4 ARCHITEKTEN GENERALPLANER
# Orbis name: POS4 ARCHITEKTEN I GENERALPLANER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: SCHIFF NIHAO GASTRONOMIE GMBH
# Orbis name: SCHIFF NIHAO GASTRONOMIE GMBH
# Name of the beneficiary: GEBR. KLOOS GMBH
# Orbis name: GEBR. KLOOS GMBH
# Name of the beneficiary: AUTOHAUS REISACHER GMBH
# Orbis name: AUTOHAUS REISACHER GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: ALPHA SERVICE GMBH
# Orbis name: ALPHA SERVICE GMBH
# Name of the beneficiary: SCHMITZ - CATERING GMBH
# Orbis name: SCHMITZ - CATERING GMBH
# Name of the beneficiary: EVIM MOBILYA GMBH
# Orbis name: EVIM MOBILYA GMBH
# Name of the beneficiary: ELEKTRO-TECHNIK RICHTER GMBH
# Orbis name: ELEKTRO-TECHNIK RICHTER GMBH
# Name of the beneficiary: COMPUTERSYSTEME DR.SCHMIDT GMB
# Orbis name: COMPUTERSYSTEME DR. SCHMIDT GMBH
# Name of the beneficiary: FK KLEBETECHNIK GMBH RESP. FRA
# Orbis name: FK KLEBETECHNIK GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: GSI OFFICE MANAGEMENT GMBH
# Orbis name: GSI OFFICE MANAGEMENT GMBH
# Name of the beneficiary: Contronix Engineering GmbH
# Orbis name: CONTRONIX ENGINEERING GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Bergmann Beton + Abwasser- technik GmbH
# Orbis name: BERGMANN BETON + ABWASSERTECHNIK GMBH
# Name of the beneficiary: plasma techology GmbH
# Orbis name: PLASMA TECHNOLOGY GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Evim Mobilya GmbH
# Orbis name: EVIM MOBILYA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Mielsch GmbH
# Orbis name: CHEG MBH
# Name of the beneficiary: Hostel Annabanana
# Orbis name: ABAN GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Kakar & Anand GbR
# Orbis name: AKA GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Kenan Yalcin
# Orbis name: K&E GMBH
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Lignante ´s Restaurant
# Orbis name: ANTE GMBH & CO. KG
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: PIPE Kenan Nuradinovic
# Orbis name: PIPE GMBH & CO.KG
# Name of the beneficiary: BEMK RECHTSANWAELTE BLAZEK ELL
# Orbis name: BEMK RECHTSANWÄLTE BLAZEK ELLERBROCK MALAR KRONSBEIN PARTGMBB
# Name of the beneficiary: SCHAEUFELE ZERFOWSKI HOLDERBAU
# Orbis name: SCHÄUFELE ZERFOWSKI HOLDERBAUM RECHTSANWÄLTE PARTG MBB
# Name of the beneficiary: Fit 24 e. K. Inhaber Thomas Schießl
# Orbis name: FIT 24 E. K.
# Invalid input. Please enter 'y' for yes or 'n' for no.
# Name of the beneficiary: Reisebüro Canan Hecht
# Orbis name: REISEBUERO GMBH
# Name of the beneficiary: Sinan Özden
# Orbis name: INAN GMBH
# Name of the beneficiary: Verein Ensemble Resonanz GbR
# Orbis name: ENSEV GMBH
# Filtered DataFrame:
#          Ref-no.                                     National ID  \
# 0    TM-10804631                                       309546985
# 1    TM-12040237                                             313
# 2    TM-11879186  339/5875/0631 Steuernummer Finanzamt Paderborn
# 3    TM-11017498                                            5175
# 4    TM-11044100                                            8042
# ..           ...                                             ...
# 476  TM-10829670                                       PR 700329
# 477  TM-12085423                      RegionNuts2021.DE219288818
# 478  TM-11035893                   Reisebüro Canan Hecht | 84032
# 479  TM-11052816                             Sinan Özden | 23568
# 480  TM-11656853            Verein Ensemble Resonanz GbR | 20359
#
#                                  processed_nid            orbis_tradeno  \
# 0                                    309546985          HRA8042Arnsberg
# 1                                          313    HRB203137Braunschweig
# 2    33958750631SteuernummerFinanzamtPaderborn             HRB22455Bonn
# 3                                         5175             HRB5175Kleve
# 4                                         8042          HRA8042Arnsberg
# ..                                         ...                      ...
# 476                                   PR700329         PR700329Mannheim
# 477                  RegionNuts2021DE219288818                      nan
# 478                   ReisebüroCananHecht84032            HRB30697Essen
# 479                            SinanÖzden23568          HRB8274Siegburg
# 480             VereinEnsembleResonanzGbR20359  HRB10615FriedbergHessen
#
#      orbis_vatno  orbis_taxno              Name of the beneficiary  \
# 0    DE309546985                                Hotel Diedrich OHG
# 1            nan          nan        Gut Gransebieth GmbH & Co. KG
# 2            nan          nan                Fa. Brunhilde Berlage
# 3    DE120277355                               Schulzek Ewald GmbH
# 4    DE309546985          nan                   Hotel Diedrich OHG
# ..           ...          ...                                  ...
# 476  DE308636734                    SCHAEUFELE ZERFOWSKI HOLDERBAU
# 477  DE219288818          nan  Fit 24 e. K. Inhaber Thomas Schießl
# 478  DE327400805          nan                Reisebüro Canan Hecht
# 479          nan  22257082072                          Sinan Özden
# 480  DE400477317          nan         Verein Ensemble Resonanz GbR
#
#                                             orbis_name        bvd_id  \
# 0                                   HOTEL DIEDRICH OHG  DE4270022476
# 1                                              UT GMBH  DE2030341008
# 2                                             RUN GMBH  DE5030719352
# 3                                  EWALD SCHULZEK GMBH  DE5130111697
# 4                                   HOTEL DIEDRICH OHG  DE4270022476
# ..                                                 ...           ...
# 476  SCHÄUFELE ZERFOWSKI HOLDERBAUM RECHTSANWÄLTE P...  DE7110057832
# 477                                       FIT 24 E. K.  DE8230368561
# 478                                    REISEBUERO GMBH  DE4090325059
# 479                                          INAN GMBH  DE5030408146
# 480                                         ENSEV GMBH  DE3490326248
#
#      nidscore  wratio  parttoksort_ratio  Unchanged  Last avail. year  \
# 0       100.0   100.0         100.000000       True            2025.0
# 1       100.0    90.0         100.000000       True            2020.0
# 2       100.0    90.0         100.000000       True            2025.0
# 3       100.0    95.0         100.000000       True            2022.0
# 4       100.0   100.0         100.000000       True            2025.0
# ..        ...     ...                ...        ...               ...
# 476     100.0    90.0          85.185185       True            2020.0
# 477     100.0    90.0          94.736842       True            2025.0
# 478     100.0    90.0         100.000000       True            2024.0
# 479     100.0    90.0         100.000000       True            2025.0
# 480     100.0    90.0         100.000000       True            2025.0
#
#     manual_similar similar
# 0             None       y
# 1             None       n
# 2             None       n
# 3             None       y
# 4             None       y
# ..             ...     ...
# 476           None       y
# 477           None       y
# 478           None       n
# 479           None       n
# 480           None       n
#
# [481 rows x 16 columns]

# %%
df_highest_year = pd.read_parquet(os.path.join(data_path, 'Matching/matched_dup_filtered.parquet'))

# %%
# Step 1: Filter out duplicates from df
# Keep only rows that are not duplicated based on 'National ID' and 'Name of the beneficiary'
df_unique = df[~df.duplicated(subset=['National ID', 'Name of the beneficiary'], keep=False)].copy()
df_unique = df_unique[(df_unique['parttoksort_ratio'] >= 80) & (df_unique['wratio'] >= 80)]

# Step 2: Append df_highest_year to the filtered df
# Ensure df_highest_year has the same columns as df
df_combined = pd.concat([df_unique, df_highest_year], ignore_index=True)

# Step 3: (Optional) Reset the index for the combined DataFrame
df_combined = df_combined.reset_index(drop=True)

df_combined.drop(columns=['similar', 'Unchanged', 'Last avail. year'], inplace=True)
# Display the resulting DataFrame
print(df_combined)
# Out:
#            Ref-no.                  National ID              processed_nid  \
# 0      TM-10116607                    HRA 20829                   HRA20829
# 1      TM-10129409                     HRB 4518                    HRB4518
# 2      TM-10116613  HRB 31202 AG Kaiserslautern                   HRB31202
# 3      TM-10116604                    HRA 11903                   HRA11903
# 4      TM-10129857                  DE303969656                DE303969656
# ...            ...                          ...                        ...
# 79197  TM-11885327                    HRB725600                  HRB725600
# 79198  TM-11028231                     HRB96083                   HRB96083
# 79199  TM-10293627                      PR 4291                     PR4291
# 79200  TM-10829670                    PR 700329                   PR700329
# 79201  TM-12085423   RegionNuts2021.DE219288818  RegionNuts2021DE219288818
#
#                 orbis_tradeno  orbis_vatno orbis_taxno  \
# 0                HRA20829Köln  DE123663836
# 1           HRB4518Deggendorf  DE277646519
# 2      HRB31202Kaiserslautern  DE279714659
# 3             HRA11903Koblenz  DE149248312
# 4                              DE303969656
# ...                       ...          ...         ...
# 79197      HRB725600Stuttgart  DE258170552         nan
# 79198           HRB96083Hanau  DE313325719         nan
# 79199             PR4291Essen  DE269638666
# 79200        PR700329Mannheim  DE308636734
# 79201                     nan  DE219288818         nan
#
#                    Name of the beneficiary  \
# 0                       AVEA GMBH & CO. KG
# 1                             FENECON GmbH
# 2                          WCI Europa GmbH
# 3             MORITZ J. WEIG GMBH & CO. KG
# 4                              Replex GmbH
# ...                                    ...
# 79197                plasma techology GmbH
# 79198                    Evim Mobilya GmbH
# 79199       BEMK RECHTSANWAELTE BLAZEK ELL
# 79200       SCHAEUFELE ZERFOWSKI HOLDERBAU
# 79201  Fit 24 e. K. Inhaber Thomas Schießl
#
#                                               orbis_name        bvd_id  \
# 0                                     AVEA GMBH & CO. KG  DE5330084939
# 1                                           FENECON GMBH  DE8230539811
# 2                                        WCI EUROPA GMBH  DE7090150809
# 3                           MORITZ J. WEIG GMBH & CO. KG  DE5170001637
# 4                                            REPLEX GMBH  DE5070363827
# ...                                                  ...           ...
# 79197                             PLASMA TECHNOLOGY GMBH  DE7330951724
# 79198                                  EVIM MOBILYA GMBH  DE6130241984
# 79199  BEMK RECHTSANWÄLTE BLAZEK ELLERBROCK MALAR KRO...  DE7130143339
# 79200  SCHÄUFELE ZERFOWSKI HOLDERBAUM RECHTSANWÄLTE P...  DE7110057832
# 79201                                       FIT 24 E. K.  DE8230368561
#
#        nidscore      wratio  parttoksort_ratio
# 0         100.0  100.000000         100.000000
# 1         100.0  100.000000         100.000000
# 2         100.0  100.000000         100.000000
# 3         100.0  100.000000         100.000000
# 4         100.0  100.000000         100.000000
# ...         ...         ...                ...
# 79197     100.0   96.969697          93.750000
# 79198     100.0  100.000000         100.000000
# 79199     100.0   90.000000          72.340426
# 79200     100.0   90.000000          85.185185
# 79201     100.0   90.000000          94.736842
#
# [79202 rows x 12 columns]

# %%
df_combined

# %%
df_combined.to_parquet(os.path.join(data_path, 'found_GER.parquet'), index=False)

# %% [markdown]
# # Cleaning: Size, Sector, and Region

# %%
df = pd.read_parquet(os.path.join(data_path, 'found_GER.parquet'))

# %%
df

# %%
# Define the path
xlsx_file_path = os.path.join(data_path, "Cleaned_from_Orbis/found_NID_GER.xlsx")  # Replace with your Excel file path

# Load the files
columns_to_load = ['Ref-no.','Name of the beneficiary','National ID']
df_xlsx = pd.read_excel(xlsx_file_path, dtype={'VAT number': str, 'Trade register number': str, 'Tax number': str})

df_xlsx.rename(columns={'Tax number': 'taxno','Trade register number': 'tradeno', 'VAT number': 'vatno'}, inplace=True)
df_xlsx = df_xlsx.drop_duplicates(subset=['BvD ID number'], keep='first')

# %%
df_xlsx

# %%
df

# %%
'''
# Get BvD ID for Orbis
df_bvd = df['BvD ID number']
output_bvd_path = os.path.join(file_path, 'BvD_ID.csv')
df_bvd.to_csv(output_bvd_path, index=False)
'''

# %%
#distinct_regions = pd.DataFrame(df['Region'].unique(), columns=['Region'])
#print(distinct_regions)

# %%
region_to_state ={
    'Baden-Wuerttemberg' : ['baden-württemberg'],
    'Bayern' : ['bayern'],
    'Berlin' : ['berlin'],
    'Brandenburg' : ['brandenburg'],
    'Bremen' : ['bremen'],
    'Hamburg' : ['hamburg'],
    'Hessen' : ['hessen'],
    'Mecklenburg-Vorpommern' : ['mecklenburg-vorpommern'],
    'Niedersachsen' : ['niedersachsen'],
    'Nordrhein-Westfalen' : ['nordrhein-westfalen'],
    'Rheinland-Pfalz' : ['rheinland-pfalz'],
    'Saarland' : ['saarland'],
    'Sachsen' : ['sachsen'],
    'Sachsen-Anhalt' : ['sachsen-anhalt'],
    'Schleswig-Holstein' : ['schleswig-holstein'],
    'Thueringen' : ['thüringen']  
}

# Custom function to map 'Region' to 'State'
def map_region_to_state(region):
    region_lower = region.lower()
    for state, regions in region_to_state.items():
        if region_lower in regions:
            return state
    return

'''
# Create the 'State' column by applying the custom function
distinct_regions['State'] = distinct_regions['Region'].apply(map_region_to_state)

# Display the resulting DataFrame
print(distinct_regions)
'''

# %%
'''
# Merge data from Orbis
prefix_ssr = 'StateAid_Size_Sector_Region_'

# List all Excel files in the directory with the specified prefix
xlsx_files = [f for f in os.listdir(file_path) if f.startswith(prefix_ssr) and f.endswith('.xlsx')]

# Initialize an empty list to store DataFrames
dataframes = []

# Process each Excel file
for xlsx_file in xlsx_files:
    # Load the Excel file
    excel_path = os.path.join(file_path, xlsx_file)
    xls = pd.ExcelFile(excel_path)
    
    # Check if the "Results" sheet exists, otherwise use the first sheet
    sheet_name = 'Results' if 'Results' in xls.sheet_names else xls.sheet_names[0]
    
    # Load the sheet into a DataFrame
    df = pd.read_excel(excel_path, sheet_name=sheet_name)
    
    #Remove the first column
    #df = df.iloc[:, 1:]

    # Append the DataFrame to the list
    dataframes.append(df)

# Merge all the DataFrames into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Define the output Excel file path
output_file_path = os.path.join(file_path, 'Merged_StateAid_Size_Sector_Region.xlsx')  # Replace with your desired output file path

# Save the merged DataFrame to a new Excel file
merged_df.to_excel(output_file_path, index=False)

print(f"Merged Excel file has been saved at: {output_file_path}")
'''

# %%
df_orbis = pd.read_excel(os.path.join(file_path, "Merged_StateAid_Size_Sector_Region.xlsx"), dtype={'NACE Rev. 2, core code (4 digits)': str})

# %%
counts = df_orbis['Type of region in country'].value_counts()
print(counts)

# %%
# Rename the first column to 'Number'
df_orbis.rename(columns={df_orbis.columns[0]: 'Number'}, inplace=True)

# Remove rows that have missing values in the 'Number' column
df_orbis = df_orbis.dropna(subset=['Number'])

# %%
#df_orbis = df_orbis[df_orbis['Type of region in country'].isna()]

# %%
merged_df = df.merge(df_orbis, on='BvD ID number', how='left')

# %%
# Map Region to State
merged_df['State'] = merged_df['Region'].apply(map_region_to_state)
# Map Region in country to Country
merged_df['State'] = merged_df['State'].fillna(merged_df['Region in country'])

# %%
# Map cities in 'National ID' to State
# Germany in Region: Stendal, München, Ludwigshafen, Mainz, Jena, Dortmund, Bochum, Dresden, Bonn
# Dictionary for 'City Latin Alphabet' to 'State'
city_to_state = {
    'Stendal': 'Sachsen-Anhalt',
    'München': 'Bayern',
    'Ludwigshafen': 'Rheinland-Pfalz',
    'Mainz': 'Rheinland-Pfalz',
    'Jena': 'Thueringen',
    'Dortmund': 'Nordrhein-Westfalen',
    'Bochum': 'Nordrhein-Westfalen',
    'Dresden': 'Sachsen',
    'Bonn': 'Nordrhein-Westfalen'
}

# Function to map city to state
def map_city_to_state(national_id):
    for city, state in city_to_state.items():
        if city.lower() in national_id.lower():
            return state
    return None

city_nationalid = merged_df[(merged_df['Region'] == 'Germany') & (merged_df['State'].isna())]
city_nationalid['State'] = city_nationalid['National ID'].apply(map_city_to_state)
merged_df.loc[city_nationalid.index, 'State'] = city_nationalid['State']

# %%
# Convert to str
merged_df['Region'] = merged_df['Region'].astype(str)
merged_df['City\nLatin Alphabet'] = merged_df['City\nLatin Alphabet'].astype(str)
merged_df['City\nLocal Alphabet'] = merged_df['City\nLocal Alphabet'].astype(str)

# %%
filtered_rows = merged_df[merged_df['State'].isna()]

unique_cities = filtered_rows['Region'].unique()
#print(unique_cities)

# More dictionary for city to state
additional_city_to_state = {
    'Unterfranken': 'Bayern',
    'Karlsruhe': 'Baden-Wuerttemberg',
    'Freising': 'Bayern',
    'Luebeck, Kreisfreie Stadt': 'Schleswig-Holstein',
    'Berchtesgadener Land': 'Bayern',
    'Lueneburg': 'Niedersachsen',
    'Oberbayern': 'Bayern',
    'Muenster': 'Nordrhein-Westfalen',
    'Hannover': 'Niedersachsen',
    'Stuttgart': 'Baden-Wuerttemberg',
    'Darmstadt': 'Hessen',
    'Niederbayern': 'Bayern',
    'Muenchen, Kreisfreie Stadt': 'Bayern',
    'Ostholstein': 'Schleswig-Holstein',
    'Koeln': 'Nordrhein-Westfalen',
    'Erzgebirgskreis': 'Sachsen',
    'Segeberg': 'Schleswig-Holstein',
    'Detmold': 'Nordrhein-Westfalen',
    'Leipzig': 'Sachsen',
    'Saarlouis': 'Saarland',
    'Duesseldorf': 'Nordrhein-Westfalen',
    'Braunschweig': 'Niedersachsen',
    'Koblenz': 'Rheinland-Pfalz',
    'Weser-Ems': 'Niedersachsen',
    'Rheinhessen-Pfalz': 'Rheinland-Pfalz',
    'Soest': 'Nordrhein-Westfalen',
    'Aurich': 'Niedersachsen',
    'Bonn, Kreisfreie Stadt': 'Nordrhein-Westfalen',
    'Bautzen': 'Sachsen',
    'Schwaben': 'Bayern',
    'Starnberg': 'Bayern',
    'Loerrach': 'Baden-Wuerttemberg',
    'Muenchen, Landkreis': 'Bayern',
    'Havelland': 'Brandenburg',
    'Helmstedt': 'Niedersachsen',
    'Dresden': 'Sachsen',
    'Ortenaukreis': 'Baden-Wuerttemberg',
    'Stuttgart, Stadtkreis': 'Baden-Wuerttemberg',
    'Karlsruhe, Stadtkreis': 'Baden-Wuerttemberg',
    'Hohenlohekreis': 'Baden-Wuerttemberg',
    'Rottal-Inn': 'Bayern',
    'Recklinghausen': 'Nordrhein-Westfalen',
    'Emden, Kreisfreie Stadt': 'Niedersachsen',
    'Region Hannover': 'Niedersachsen',
    'Gelsenkirchen, Kreisfreie Stadt': 'Nordrhein-Westfalen',
    'Ludwigshafen am Rhein, Kreisfreie Stadt': 'Rheinland-Pfalz',
    'Freiburg im Breisgau, Stadtkreis': 'Baden-Wuerttemberg',
    'Duesseldorf, Kreisfreie Stadt': 'Nordrhein-Westfalen',
    'Paderborn': 'Nordrhein-Westfalen',
    'Neuburg-Schrobenhausen': 'Bayern',
    'Main-Kinzig-Kreis': 'Hessen',
    'Hof, Landkreis': 'Bayern',
    'Essen': 'Nordrhein-Westfalen',
    'Duisburg, Kreisfreie Stadt': 'Nordrhein-Westfalen',
    'Bochum, Kreisfreie Stadt': 'Nordrhein-Westfalen',
    'Guetersloh': 'Nordrhein-Westfalen',
    'Wartburgkreis': 'Thueringen',
    'Karlsruhe, Landkreis': 'Baden-Wuerttemberg',
    'Ravensburg': 'Baden-Wuerttemberg',
    'Saale-Orla-Kreis': 'Thueringen',
    'Jena, Kreisfreie Stadt': 'Thueringen',
    'Vorpommern-Greifswald': 'Mecklenburg-Vorpommern',
    'Wesel': 'Nordrhein-Westfalen',
    'Oberpfalz': 'Bayern',
    'Freyung-Grafenau': 'Bayern',
    'Ansbach, Landkreis': 'Bayern',
    'Frankfurt am Main, Kreisfreie Stadt': 'Hessen',
    'Tuebingen': 'Baden-Wuerttemberg',
    'Arnsberg': 'Nordrhein-Westfalen',
    'Freiburg': 'Baden-Wuerttemberg',
    'Kassel': 'Hessen',
    'Chemnitz': 'Sachsen',
    'Mainz-Bingen': 'Rheinland-Pfalz',
    'Coesfeld': 'Nordrhein-Westfalen',
    'Heilbronn, Landkreis': 'Baden-Wuerttemberg',
    'Kleve': 'Nordrhein-Westfalen',
    'Saalekreis': 'Sachsen-Anhalt',
    'Weilheim-Schongau': 'Bayern',
    'Marburg-Biedenkopf': 'Hessen',
    'Mittelfranken': 'Bayern',
    'Neckar-Odenwald-Kreis': 'Baden-Wuerttemberg',
    'Biberach': 'Baden-Wuerttemberg',
    'Altoetting': 'Bayern',
    'Bad Kreuznach': 'Rheinland-Pfalz',
    'Muenchen' : 'Bayern',
    'GTTTINGEN' : 'Niedersachsen',
    'MAGDEBURG' : 'Sachsen-Anhalt',
    'Stuttgart' : 'Baden-Wuerttemberg',
    'Hannover' : 'Niedersachsen',
    'Münster' : 'Nordrhein-Westfalen',
    'Oberbayern' : 'Bayern',
    'AMBERG' : 'Bayern',
    'Altötting' : 'Bayern',
    "Köln" : 'Nordrhein-Westfalen',
    'Düsseldorf' : 'Nordrhein-Westfalen',
    'Lüneburg' : 'Niedersachsen',
    'Lübeck' : 'Schleswig-Holstein',
    'Lörrach' : 'Baden-Wuerttemberg',
    'Gütersloh' : 'Nordrhein-Westfalen',
    'Tübingen' : 'Baden-Wuerttemberg',
    'MSNCHEN' : 'Bayern',
    'Berlin' : 'Berlin',
    'BAD HOMBURG' : 'Hessen',
    'DÜSSELDOPRF' : 'Nordrhein-Westfalen',
    'asperg' : 'Baden-Wuerttemberg',
    'hagen' : 'Nordrhein-Westfalen',
    'oberstdorf' : 'Bayern',
    'MANNHEIM' : 'Baden-Wuerttemberg',
    'ROSENHEIM' : 'Bayern',
    'HALLSTADT' : 'Bayern',
    'KAISERSLAUTERN' : 'Rheinland-Pfalz',
    'hagen' : 'Nordrhein-Westfalen',
    'bremen' : 'Bremen',
    'NÜRNBERG' : 'Bayern',
    'bismark' : 'Sachsen-Anhalt',
    'SCHONAU AM KONIGSSEE' : 'Bayern',
    'MÜLHEIM' : 'Nordrhein-Westfalen',
    'AACHEN' : 'Nordrhein-Westfalen',
    'WEITERSTADT' : 'Hessen',
    'LIMBACH-OBERFROHNA' : 'Sachsen',
    'MUNCHEN': 'Bayern',
    'WARTMANNSROTH': 'Bayern',
    'HÖXTER': 'Nordrhein-Westfalen',
    'WESTERSTEDE': 'Niedersachsen',
    'TRIER': 'Rheinland-Pfalz',
    'OSTBEVERN': 'Nordrhein-Westfalen',
    'LUDWIGSBURG': 'Baden-Wuerttemberg',
    'LANGELSHEIM': 'Niedersachsen',
    'HOCHHEIM AM MAIN': 'Hessen',
    'HIDDENHAUSEN': 'Nordrhein-Westfalen',
    'GRÄFENRODA': 'Thueringen',
    'GERATAL': 'Thueringen',
    'ERLANGEN': 'Bayern',
    'EINBECK': 'Niedersachsen',
    'DSSSELDORF': 'Nordrhein-Westfalen'
}

city_to_state.update(additional_city_to_state)

# %%
# Filter rows where 'State' is missing and 'Region'
filtered_rows = merged_df[merged_df['State'].isna()]

# Apply the city to state mapping function to the 'City Latin Alphabet' column
filtered_rows['State'] = filtered_rows['Region'].apply(map_city_to_state)

# Fill in the 'State' column in the original DataFrame
merged_df.loc[filtered_rows.index, 'State'] = filtered_rows['State']

# %%
# Filter rows where 'State' is missing and 'Region' is 'Germany'
filtered_rows = merged_df[(merged_df['State'].isna()) & (merged_df['Region'] == 'Germany')]

# Apply the city to state mapping function to the 'City Latin Alphabet' column
filtered_rows['State'] = filtered_rows['City\nLocal Alphabet'].apply(map_city_to_state)

# Fill in the 'State' column in the original DataFrame
merged_df.loc[filtered_rows.index, 'State'] = filtered_rows['State']

# %%
# Rename "NACE Rev. 2, core code (4 digits)" to "nace_code"
merged_df.rename(columns={'NACE Rev. 2, core code (4 digits)': 'nace_code'}, inplace=True)
merged_df['nace_code'] = merged_df['nace_code'].astype(str)

# %%
filtered_rows = merged_df[merged_df['nace_code'].isna()]

missing_sector_to_nacecode = {
    'Wired telecommunications activities': '6110',
    'Manufacture of other fabricated metal products n.e.c.': '2599',
    'Electric power generation, transmission and distribution': '3511',
    'Manufacture of basic iron and steel and of ferro-alloys': '2410',
    'Hotels and similar accommodation': '5510',
    'Repair and maintenance of other transport equipment': '3317',
    'Travel agency and tour operator activities': '7911',
    'Wholesale of agricultural machinery, equipment and supplies': '4661',
    'Other specialised construction activities n.e.c.': '4399',
    'Retail sale of furniture, lighting equipment and other household articles in specialised stores': '4759',
    'Wholesale and retail trade and repair of motor vehicles and motorcycles': '4510',
    'Retail sale of sporting equipment in specialised stores': '4764',
    'Manufacture of metal structures and parts of structures': '2512',
    'Retail sale of clothing in specialised stores': '4771',
    'Water transport': '5040',
    'Management of real estate on a fee or contract basis': '6832',
    'Manufacture of other chemical products': '2059',
    'WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VEHICLES AND MOTORCYCLES': '4500',
    'Manufacture of lifting and handling equipment': '2822',
    'Manufacture of basic metals': '2400', 
    'Manufacture of doors and windows of metal': '2512',
    'Scientific research and development': '7211',
    'Raising of swine/pigs': '0146',
    'Restaurants and mobile food service activities': '5610',
    'Crop and animal production, hunting and related service activities': '0100',
    'Mixed farming': '0150',
    'Raising of dairy cattle': '0141',
    'Manufacture of prepared pet foods': '1092',
    'Other research and experimental development on natural sciences and engineering': '7219',
    'Manufacture of vegetable and animal oils and fats': '1041',
    'Wholesale of grain, unmanufactured tobacco, seeds and animal feeds': '4621',
    'Production of meat and poultry meat products': '1013',
    'Retail sale via mail order houses or via Internet': '4791',
    'Animal production': '0140',
}

def map_sector_to_nacecode(sector):
    for sector_name, nace_code in missing_sector_to_nacecode.items():
        if sector_name.lower() in sector.lower():
            return nace_code
    return None

# Apply to missing values
filtered_rows['nace_code'] = filtered_rows['Sector (NACE)'].apply(map_sector_to_nacecode)
merged_df.loc[filtered_rows.index, 'nace_code'] = filtered_rows['nace_code']

# %%
# Add '0' to rows with 3 digits in 'nace_code'
merged_df['nace_code'] = merged_df['nace_code'].apply(lambda x: x.zfill(4) if len(x) == 3 else x)

# %%
# Correct nace code of 0100, 1000, and 1010, and one specific company with 9810
filtered_rows = merged_df[merged_df['nace_code'].str.contains(r'^(0100|1000|1010|9810)$', na=False)]
filtered_rows['nace_code'] = filtered_rows['Sector (NACE)'].apply(map_sector_to_nacecode)
merged_df.loc[filtered_rows.index, 'nace_code'] = filtered_rows['nace_code']

# %%
#print(merged_df['NACE Rev. 2, core code (4 digits)'].unique())

# %%
# Drop rows without 'State' and Aid amount
merged_df['no_aid_amount'] = merged_df['Aid element, expressed as full amount'].apply(lambda x: 1 if any(char in str(x) for char in ['>', '<', '-']) else 0)
merged_df = merged_df.dropna(subset=['State', 'Aid element, expressed as full amount'])
merged_df = merged_df[merged_df['no_aid_amount'] == 0]

# %%
# Define the file path for the NoEmp.xlsx file
noemp_file_path = os.path.join(file_path, "NoEmp.xlsx")

# Import the specific sheet "Result" from the NoEmp.xlsx file
df_noemp = pd.read_excel(noemp_file_path, sheet_name="Results")

# Rename column 'Number of employees\nLast avail. yr' to 'NumEmp'
df_noemp.rename(columns={'Number of employees\nLast avail. yr': 'NumEmp'}, inplace=True)

# Merge the 'Number of employees Last avail. yr' column from df_noemp into merged_df based on 'BvD ID number'
merged_df = merged_df.merge(df_noemp[['BvD ID number', 'NumEmp']], on='BvD ID number', how='left')

# %%
# Export
output_path = os.path.join(file_path, 'with_aid_state_5.csv')
merged_df.to_csv(output_path, index=False)

# %% [markdown]
# # Descriptive Stats: Size, Sector, and Region

# %%
# Load file
df = pd.read_csv(os.path.join(file_path, 'with_aid_state_5.csv'),dtype={'nace_code': str})

# %%
# Dataset with unique firms
df_nodup = df.drop_duplicates(subset='BvD ID number'), keep='first')

# %%
# Replace "n.a." with NaN
df_nodup['NumEmp'] = df_nodup['NumEmp'].replace("n.a.", np.nan)

# Convert the 'NumEmp' column to numeric
df_nodup['NumEmp'] = pd.to_numeric(df_nodup['NumEmp'], errors='coerce')

# Drop rows with missing values in the 'NumEmp' column
df_nodup = df_nodup.dropna(subset=['NumEmp'])

# Define the bins and labels for the ranges
bins = [0, 9, 19, 49, 99, 249, float('inf')]
labels = ['1-9', '10-19', '20-49', '50-99', '100-249', '250+']

# Classify firms into the specified ranges
df_nodup['Firm Size'] = pd.cut(df_nodup['NumEmp'], bins=bins, labels=labels, right=True)

# Count the number of firms in each range
firm_size_distribution = df_nodup['Firm Size'].value_counts().sort_index().reset_index()
firm_size_distribution.columns = ['Firm Size', 'Firm Count']

# Count the number of firms with missing values in 'NumEmp'
missing_count = df_nodup['NumEmp'].isna().sum()
missing_row = pd.DataFrame([['Missing', missing_count]], columns=['Firm Size', 'Firm Count'])

# Append the missing row to the distribution table
firm_size_distribution = pd.concat([firm_size_distribution, missing_row], ignore_index=True)

# Calculate the percentage of firm count
total_firms = firm_size_distribution['Firm Count'].sum()
firm_size_distribution['Percentage'] = (firm_size_distribution['Firm Count'] / total_firms) * 100

# Round the percentage to 2 digits after the decimal separator
firm_size_distribution['Percentage'] = firm_size_distribution['Percentage'].round(2)

# Custom formatting function to display "<0.01" for values equal to 0.00
def format_percentage(value):
    return "<0.01" if value == 0.00 else f"{value:.2f}"

# Apply the custom formatting function to the 'Percentage' column
firm_size_distribution['Percentage'] = firm_size_distribution['Percentage'].apply(format_percentage)

# Add a final row to sum all the firm counts to get the total number of firms
total_row = pd.DataFrame([['Total', total_firms, '100.00']], columns=['Firm Size', 'Firm Count', 'Percentage'])
firm_size_distribution = pd.concat([firm_size_distribution, total_row], ignore_index=True)

# Display the resulting table
print(firm_size_distribution)

# Latex
latex_table = firm_size_distribution.to_latex(index=False)
print(latex_table)
# Out:
#   Firm Size  Firm Count Percentage
# 0       1-9       14894      27.02
# 1     10-19       10969      19.90
# 2     20-49       14688      26.65
# 3     50-99        6387      11.59
# 4   100-249        4264       7.74
# 5      250+        3911       7.10
# 6   Missing           0      <0.01
# 7     Total       55113     100.00
# \begin{tabular}{lrl}
# \toprule
# Firm Size & Firm Count & Percentage \\
# \midrule
# 1-9 & 14894 & 27.02 \\
# 10-19 & 10969 & 19.90 \\
# 20-49 & 14688 & 26.65 \\
# 50-99 & 6387 & 11.59 \\
# 100-249 & 4264 & 7.74 \\
# 250+ & 3911 & 7.10 \\
# Missing & 0 & <0.01 \\
# Total & 55113 & 100.00 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_110029/1675525726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['NumEmp'] = df_nodup['NumEmp'].replace("n.a.", np.nan)
# /tmp/ipykernel_110029/1675525726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['NumEmp'] = pd.to_numeric(df_nodup['NumEmp'], errors='coerce')

# %%
# Create a mapping dictionary for the first two digits of the nace_code to sector descriptions
nace_sector_mapping = {
    '01': 'A: AGRICULTURE, FORESTRY AND FISHING',
    '02': 'A: AGRICULTURE, FORESTRY AND FISHING',
    '03': 'A: AGRICULTURE, FORESTRY AND FISHING',
    '05': 'B: MINING AND QUARRYING',
    '06': 'B: MINING AND QUARRYING',
    '07': 'B: MINING AND QUARRYING',
    '08': 'B: MINING AND QUARRYING',
    '09': 'B: MINING AND QUARRYING',
    '10': 'C: MANUFACTURING',
    '11': 'C: MANUFACTURING',
    '12': 'C: MANUFACTURING',
    '13': 'C: MANUFACTURING',
    '14': 'C: MANUFACTURING',
    '15': 'C: MANUFACTURING',
    '16': 'C: MANUFACTURING',
    '17': 'C: MANUFACTURING',
    '18': 'C: MANUFACTURING',
    '19': 'C: MANUFACTURING',
    '20': 'C: MANUFACTURING',
    '21': 'C: MANUFACTURING',
    '22': 'C: MANUFACTURING',
    '23': 'C: MANUFACTURING',
    '24': 'C: MANUFACTURING',
    '25': 'C: MANUFACTURING',
    '26': 'C: MANUFACTURING',
    '27': 'C: MANUFACTURING',
    '28': 'C: MANUFACTURING',
    '29': 'C: MANUFACTURING',
    '30': 'C: MANUFACTURING',
    '31': 'C: MANUFACTURING',
    '32': 'C: MANUFACTURING',
    '33': 'C: MANUFACTURING',
    '35': 'D: ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY',
    '36': 'E: WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES',
    '37': 'E: WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES',
    '38': 'E: WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES',
    '39': 'E: WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES',
    '41': 'F: CONSTRUCTION',
    '42': 'F: CONSTRUCTION',
    '43': 'F: CONSTRUCTION',
    '45': 'G: WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VEHICLES AND MOTORCYCLES',
    '46': 'G: WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VEHICLES AND MOTORCYCLES',
    '47': 'G: WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VEHICLES AND MOTORCYCLES',
    '49': 'H: TRANSPORTATION AND STORAGE',
    '50': 'H: TRANSPORTATION AND STORAGE',
    '51': 'H: TRANSPORTATION AND STORAGE',
    '52': 'H: TRANSPORTATION AND STORAGE',
    '53': 'H: TRANSPORTATION AND STORAGE',
    '55': 'I: ACCOMMODATION AND FOOD SERVICE ACTIVITIES',
    '56': 'I: ACCOMMODATION AND FOOD SERVICE ACTIVITIES',
    '58': 'J: INFORMATION AND COMMUNICATION',
    '59': 'J: INFORMATION AND COMMUNICATION',
    '60': 'J: INFORMATION AND COMMUNICATION',
    '61': 'J: INFORMATION AND COMMUNICATION',
    '62': 'J: INFORMATION AND COMMUNICATION',
    '63': 'J: INFORMATION AND COMMUNICATION',
    '64': 'K: FINANCIAL AND INSURANCE ACTIVITIES',
    '65': 'K: FINANCIAL AND INSURANCE ACTIVITIES',
    '66': 'K: FINANCIAL AND INSURANCE ACTIVITIES',
    '68': 'L: REAL ESTATE ACTIVITIES',
    '69': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '70': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '71': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '72': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '73': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '74': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '75': 'M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES',
    '77': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '78': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '79': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '80': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '81': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '82': 'N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES',
    '84': 'O: PUBLIC ADMINISTRATION AND DEFENCE; COMPULSORY SOCIAL SECURITY',
    '85': 'P: EDUCATION',
    '86': 'Q: HUMAN HEALTH AND SOCIAL WORK ACTIVITIES',
    '87': 'Q: HUMAN HEALTH AND SOCIAL WORK ACTIVITIES',
    '88': 'Q: HUMAN HEALTH AND SOCIAL WORK ACTIVITIES',
    '90': 'R: ARTS, ENTERTAINMENT AND RECREATION',
    '91': 'R: ARTS, ENTERTAINMENT AND RECREATION',
    '92': 'R: ARTS, ENTERTAINMENT AND RECREATION',
    '93': 'R: ARTS, ENTERTAINMENT AND RECREATION',
    '94': 'S: OTHER SERVICE ACTIVITIES',
    '95': 'S: OTHER SERVICE ACTIVITIES',
    '96': 'S: OTHER SERVICE ACTIVITIES',
    '97': 'T: ACTIVITIES OF HOUSEHOLDS AS EMPLOYERS; UNDIFFERENTIATED GOODS- AND SERVICES-PRODUCING ACTIVITIES OF HOUSEHOLDS FOR OWN USE',
    '98': 'T: ACTIVITIES OF HOUSEHOLDS AS EMPLOYERS; UNDIFFERENTIATED GOODS- AND SERVICES-PRODUCING ACTIVITIES OF HOUSEHOLDS FOR OWN USE',
    '99': 'U: ACTIVITIES OF EXTRATERRITORIAL ORGANIZATIONS AND BODIES'
}

#Extract the first two digits of the 'nace_code' to determine the sector
df_nodup['sector_code'] = df_nodup['nace_code'].str[:2]

# Map the sectors using the mapping dictionary
df_nodup['sector'] = df_nodup['sector_code'].map(nace_sector_mapping)

# Group by sector to count the number of firms in each sector
sector_distribution = df_nodup['sector'].value_counts().reset_index()
sector_distribution.columns = ['Sector', 'Firm Count']

# Calculate the percentage of firm count
total_firms = sector_distribution['Firm Count'].sum()
sector_distribution['Percentage'] = (sector_distribution['Firm Count'] / total_firms) * 100

# Round the percentage to 2 digits after the decimal separator
sector_distribution['Percentage'] = sector_distribution['Percentage'].round(2)

# Custom formatting function to display "<0.01" for values equal to 0.00
def format_percentage(value):
    return "<0.01" if value == 0.00 else f"{value:.2f}"

# Apply the custom formatting function to the 'Percentage' column
sector_distribution['Percentage'] = sector_distribution['Percentage'].apply(format_percentage)

# Sort the table by the sector codes in alphabetical order
sector_distribution = sector_distribution.sort_values(by='Sector')

# Add a final row to sum all the firm counts to get the total number of firms
total_row = pd.DataFrame([['Total', total_firms, '100.00']], columns=['Sector', 'Firm Count', 'Percentage'])
sector_distribution = pd.concat([sector_distribution, total_row], ignore_index=True)


# Convert the DataFrame to a LaTeX tabularx environment
latex_table = sector_distribution.to_latex(index=False)

# Display the resulting table
print(latex_table)
# Out:
# \begin{tabular}{lrl}
# \toprule
# Sector & Firm Count & Percentage \\
# \midrule
# A: AGRICULTURE, FORESTRY AND FISHING & 814 & 1.48 \\
# B: MINING AND QUARRYING & 95 & 0.17 \\
# C: MANUFACTURING & 12261 & 22.25 \\
# D: ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY & 1023 & 1.86 \\
# E: WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION ACTIVITIES & 417 & 0.76 \\
# F: CONSTRUCTION & 2919 & 5.30 \\
# G: WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VEHICLES AND MOTORCYCLES & 10389 & 18.85 \\
# H: TRANSPORTATION AND STORAGE & 2603 & 4.72 \\
# I: ACCOMMODATION AND FOOD SERVICE ACTIVITIES & 5594 & 10.15 \\
# J: INFORMATION AND COMMUNICATION & 3011 & 5.46 \\
# K: FINANCIAL AND INSURANCE ACTIVITIES & 776 & 1.41 \\
# L: REAL ESTATE ACTIVITIES & 1225 & 2.22 \\
# M: PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES & 5038 & 9.14 \\
# N: ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES & 4003 & 7.26 \\
# O: PUBLIC ADMINISTRATION AND DEFENCE; COMPULSORY SOCIAL SECURITY & 47 & 0.09 \\
# P: EDUCATION & 421 & 0.76 \\
# Q: HUMAN HEALTH AND SOCIAL WORK ACTIVITIES & 1043 & 1.89 \\
# R: ARTS, ENTERTAINMENT AND RECREATION & 2173 & 3.94 \\
# S: OTHER SERVICE ACTIVITIES & 1261 & 2.29 \\
# Total & 55113 & 100.00 \\
# \bottomrule
# \end{tabular}

# %%
# Count the number of firms in each state
state_distribution = df_nodup['State'].value_counts().reset_index()
state_distribution.columns = ['State', 'Firm Count']

# Calculate the percentage of firm count
total_firms = state_distribution['Firm Count'].sum()
state_distribution['Percentage'] = (state_distribution['Firm Count'] / total_firms) * 100

# Round the percentage to 2 digits after the decimal separator
state_distribution['Percentage'] = state_distribution['Percentage'].round(2)

# Custom formatting function to display "<0.01" for values equal to 0.00
def format_percentage(value):
    return "<0.01" if value == 0.00 else f"{value:.2f}"

# Apply the custom formatting function to the 'Percentage' column
state_distribution['Percentage'] = state_distribution['Percentage'].apply(format_percentage)

# Sort the table by the number of firm counts in descending order
state_distribution = state_distribution.sort_values(by='Firm Count', ascending=False)

# Add a final row to sum all the firm counts to get the total number of firms
total_row = pd.DataFrame([['Total', total_firms, '100.00']], columns=['State', 'Firm Count', 'Percentage'])
state_distribution = pd.concat([state_distribution, total_row], ignore_index=True)

# Display the resulting table
print(state_distribution)

# Convert the DataFrame to a LaTeX tabular environment
latex_table = state_distribution.to_latex(index=False)
print(latex_table)
# Out:
#                      State  Firm Count Percentage
# 0      Nordrhein-Westfalen       13003      23.59
# 1                   Bayern       10898      19.77
# 2       Baden-Wuerttemberg        6756      12.26
# 3                   Hessen        4403       7.99
# 4            Niedersachsen        3601       6.53
# 5          Rheinland-Pfalz        2566       4.66
# 6                   Berlin        2483       4.51
# 7                  Hamburg        2069       3.75
# 8                  Sachsen        2043       3.71
# 9       Schleswig-Holstein        1520       2.76
# 10              Thueringen        1270       2.30
# 11          Sachsen-Anhalt        1254       2.28
# 12  Mecklenburg-Vorpommern        1120       2.03
# 13             Brandenburg        1111       2.02
# 14                Saarland         671       1.22
# 15                  Bremen         345       0.63
# 16                   Total       55113     100.00
# \begin{tabular}{lrl}
# \toprule
# State & Firm Count & Percentage \\
# \midrule
# Nordrhein-Westfalen & 13003 & 23.59 \\
# Bayern & 10898 & 19.77 \\
# Baden-Wuerttemberg & 6756 & 12.26 \\
# Hessen & 4403 & 7.99 \\
# Niedersachsen & 3601 & 6.53 \\
# Rheinland-Pfalz & 2566 & 4.66 \\
# Berlin & 2483 & 4.51 \\
# Hamburg & 2069 & 3.75 \\
# Sachsen & 2043 & 3.71 \\
# Schleswig-Holstein & 1520 & 2.76 \\
# Thueringen & 1270 & 2.30 \\
# Sachsen-Anhalt & 1254 & 2.28 \\
# Mecklenburg-Vorpommern & 1120 & 2.03 \\
# Brandenburg & 1111 & 2.02 \\
# Saarland & 671 & 1.22 \\
# Bremen & 345 & 0.63 \\
# Total & 55113 & 100.00 \\
# \bottomrule
# \end{tabular}
